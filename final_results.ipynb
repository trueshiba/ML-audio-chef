# %% [markdown]
# ## CS 5990: Advanced Machine Learning Final Project
#
# Mish Wilson and Cooper Sullivan
#
# 10/23/2024

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write
from IPython.display import Audio
from numpy.fft import fft, ifft
from os.path import dirname, join as pjoin
from scipy.io import wavfile

import torch
import torchaudio
import torch.nn as nn

import scipy.io 
import os

import csv
import pandas as pd
from torchvision.io import read_image
from torch.utils.data import DataLoader, Dataset, random_split, Subset

# %matplotlib inline

import math, random
from pathlib import Path
import soundfile

from itertools import combinations
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sn
from torchsummary import summary

# %%
# Test to see current working directory w correct files listed
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  'classID.csv',
#  'clips_rd',
#  'load.py',
#  'metadeta.csv',
#  'prelim_results.ipynb',
#  'README.md',
#  'requirements.txt',
#  'tensor.pt',
#  'text_zone(2).ipynb',
#  'text_zone.ipynb']

# %%
# Test if we can read single file and get samplerate and data attributes
data_dir = pjoin(os.curdir, '.\clips_rd', 'aloe')
wav_fname = pjoin(data_dir, 'aloe_1_02.wav')
samplerate, data = wavfile.read(wav_fname)
print(f"length = {data.shape[0] / samplerate}s")
print(data.shape)
# Out:
# length = 2.9872562358276644s
# (131738,)
# C:\Users\cojas\AppData\Local\Temp\ipykernel_15636\4114016665.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, data = wavfile.read(wav_fname)

# %%
# Read single audio clip with regular IO function and call as audio
Fs, data = read('./clips_rd/aloe/aloe_1_02.wav')

Audio(data, rate=Fs)
# Out:
# C:\Users\cojas\AppData\Local\Temp\ipykernel_15636\311687441.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   Fs, data = read('./clips_rd/aloe/aloe_1_02.wav')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Plot waveform to visualize audio
plt.figure(figsize=(10, 4))
plt.plot(data)
plt.xlabel("Sample Index")
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()

# %% [markdown]
# Each audio sample in the dataset such as its filename, its class label, the ‘fold’ sub-folder location, and so on.
#
# We will create a CSV to store path data for loading. Format: relative_path, classID, label

# %%
# Display food labels
path = os.getcwd() + "/clips_rd" 
food_categories = os.listdir(path) 
print("Files and directories in '", path, "' :")  
print(food_categories)
# Out:
# Files and directories in ' c:\Users\cojas\Documents\machineLearning\finalProject\ML-audio-chef/clips_rd ' :
# ['aloe', 'burger', 'cabbage', 'candied_fruits', 'carrots', 'chips', 'chocolate', 'drinks', 'fries', 'grapes', 'gummies', 'ice-cream', 'jelly', 'noodles', 'pickles', 'pizza', 'ribs', 'salmon', 'soup', 'wings']

# %%
# Create general CSV for label referencing

data = [['class', 'classID']]
for i, food in enumerate(food_categories):
    data.append([food, i+1])

# Create file path for the CSV file
csv_file_path = 'classID.csv'

# Open the file in write mode
with open(csv_file_path, mode='w', newline='') as file:
    # Create a csv.writer object
    writer = csv.writer(file)
    # Write data to the CSV file
    writer.writerows(data)

# %%
# Create metadata CSV file to store audio paths as well as ID and labels

data = [['relative_path', 'classID', 'label','video']]
for i, food in enumerate(food_categories):
    path = os.getcwd() + "\\clips_rd\\" + food
    wavs = os.listdir(path)
    for wav in wavs:
        video = wav.split("_")[1]
        if video == "fruits":
            video = wav.split("_")[2]
        data.append([f"./clips_rd/{food}/{wav}",i, food,video])

# File path for the CSV file
csv_file_path = 'metadeta.csv'

# Open the file in write mode
with open(csv_file_path, mode='w', newline='') as file:
    # Create a csv.writer object
    writer = csv.writer(file)
    # Write data to the CSV file
    writer.writerows(data)

# %% [markdown]
# ## Tranforming Data / Audio Files
#
# Here we transform the data so that its in a format the model expects. This can be done during runtime.
#
# Audio files tend to be large- so we're keeping only the audio file names in our taining data.
#
# Then at run time, as we train the model we'll load the audio data for that bath and then process it. This way we keep audiodata for only one batch in memory at a time reducing the overall strain on system by loading everything in all at once and having to store it all.
#
# Transforms:
# - Load Audio file
# - Resample and convert to stereo or mono
#     - Testing on aloe- so far all the files seem to have 1 channel so no need to convert them!
# - resize to fixed length so all the audios are the same length
# - audio augmentation time shift
# - convert to mel spectogram
# - spectogram augmentation. SPECAUGMENTATING TIME!!

# %% [markdown]
# Potential audio processing libraries:
# - librosa
#     - slower that pytorch
#     - seems to be used for smaller datasets?
#     - usually used for making spectograms- but since pytorch came out with torchaudio it isn't used as much by new learners- usually used by people who are used to the library.
# - pytorch (torchaudio)
#     - pretty fast
#     - may be better for such a large data set
#     - well documented (in my opinion)
#     - we'll be using pytorch anyway to processed the spectrogram- so we probably should just use torchaudio??
# - audio flux
#     - super fast
#     - fairly new
#     - less digital examples to follow when learning

# %% [markdown]
# ## Load in Data

# %%
torchaudio.set_audio_backend("soundfile")

def open_audio(audio_file):
    signal, sample_rate = torchaudio.load(f"{os.getcwd()}{audio_file}")
    return signal, sample_rate

df = pd.read_csv('metadeta.csv')

# Check if audio file backend exists
# Output should be ['soundfile']. If output is [] then redownload libraries in specific order.
print(torchaudio.list_audio_backends())
# Out:
# C:\Users\cojas\AppData\Local\Temp\ipykernel_15636\242481931.py:1: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# ['soundfile']

# %% [markdown]
# ### Test to ensure audio files load properly

# %%
# Using Open Audio, for now we're just using aloe
audio_files = []

# Keep track incase not all files are correctly loaded
success = 0
fail = 0

for audio in df[df['label'].isin(["aloe", "burger"])]['relative_path']:
    try:
        audio_files.append(open_audio(audio))
        success += 1
    except RuntimeError:
        fail += 1
        print(f"Skipping file: {audio}")
print(f"Successes: {success}\nFails: {fail}")
# Out:
# Successes: 1141
# Fails: 0

# %% [markdown]
# ## Audio Before Transformations

# %%
waveform, sr = audio_files[1]
fig, axs = plt.subplots(1, 1)

waveform = waveform.numpy()
num_channels, num_frames = waveform.shape
time_axis = torch.arange(0, num_frames) / sr

ax = axs
ax.plot(time_axis, waveform[0], linewidth=1)
ax.grid(True)
ax.set_xlim([0, time_axis[-1]])
ax.set_title("Original Waveform")
# Out:
# Text(0.5, 1.0, 'Original Waveform')

# %% [markdown]
# ## Transform Sample Rate
# Just looping through and making sure all the audio files have the same sample rate! Majority seem to be 44100Hz- but just to make sure I'll loop through to catch any that aren't.

# %%
# Resample takes in audio file (aud) and desired sample rate (newsr) and ensures they match
def resample(aud, newsr):
    signal, sr = aud

    if (sr == newsr):
      return audio
        
    # Resample channel
    re_signal = torchaudio.transforms.Resample(sr, newsr)(signal[:1,:])
    

    return ((re_signal, newsr))

# %%
# Loop through and resample all audio so its on the same page (44100Hz)
t_audio_files = []
for audio in audio_files:
    t_audio_files.append(resample(audio, 44100))

audio_files = t_audio_files

# %% [markdown]
# ## Resizing Audio Lengths
#
# Resizing  samples to be the same length. Found that they are infact different lengths ranging between 2 and 4? I think I'll just average it out to 3 seconds each. Padding it out with silence if its 2 seconds and truncating if its 4? We can change this if this is bad.
#
# Math to find length of clips:
# Sample Rate // 44100 Hz

# %%
def resize(aud, max_ms):
    signal, sample_rate = aud
    num_rows, signal_len = signal.shape

    # calculate what would make audio max_ms long
    max_len = sample_rate//1000 * max_ms

    if (signal_len > max_len):
      # Truncate signal
      signal = signal[:,:max_len]

    elif (signal_len < max_len):
      # Pad audio with silence instead. At beginning and end.
      pad_begin_len = random.randint(0, max_len - signal_len)
      pad_end_len = max_len - signal_len - pad_begin_len

      # Pad with 0s
      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))

      signal = torch.cat((pad_begin, signal, pad_end), 1)
      
    return (signal, sample_rate)

# %%
# Loop through and resize all audio so they're all 3 seconds long (3000 miliseconds)
t_audio_files = []
for audio in audio_files:
    t_audio_files.append(resize(audio, 3000))

audio_files = t_audio_files

# %% [markdown]
# ## Time Shift
# Not sure if its necessary to do this augmentation since I think we have a pretty diverse dataset? But we can return to this if we need to.

# %% [markdown]
# ## Mel Spectrogram Creation.
#
# Time to creat some spectrograms! Specifically Mel Spectrograms instead of jsut Spectrograms as they are better for training models it seems.
#
# "The mel-spectrogram, based on the auditory-based mel-frequency scale, provides better resolution for lower frequencies than the spectrogram"

# %%
# n_mels : Number of mel filterbanks
# n_fft : Size of FFT
# hop_len : Length of hop between STFT windows
def spectrogram(audio, n_mels=64, n_fft=1024, hop_len=None):
    signal, sample_rate = audio
    top_db = 80

    # spectrogram shape is [channel, n_mels, time]
    spec = torchaudio.transforms.MelSpectrogram(sample_rate, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(signal)

    # Convert to decibels 
    spec = torchaudio.transforms.AmplitudeToDB(top_db=top_db)(spec)
    return spec

# %%
spec = spectrogram(audio_files[1])

# %%
def plot_spectrogram(spec, title='Spectrogram'):
    # Convert the tensor to a numpy array and squeeze to 2D
    spec = spec.squeeze().numpy()

    plt.figure(figsize=(10, 4))
    plt.imshow(spec, aspect='auto', origin='lower')
    plt.colorbar()
    plt.title(title)
    plt.xlabel('Time (frames)')
    plt.ylabel('Mel frequency bins')
    return plt

# plot_spectrogram(spec, title='Spectrogram')

spec = spectrogram(audio_files[1])
waveform, sr = audio_files[1]
fig, axs = plt.subplots(2, 1)

waveform = waveform.numpy()
num_channels, num_frames = waveform.shape
time_axis = torch.arange(0, num_frames) / sr

ax = axs[0]
ax.plot(time_axis, waveform[0], linewidth=1)
ax.grid(True)
ax.set_xlim([0, time_axis[-1]])
ax.set_title("Original Waveform")

s_spec = spec.squeeze().numpy()

ax = axs[1]
ax.imshow(s_spec, aspect='auto', origin='lower')
ax.set_title("Spectrogram")
ax.set_xlabel('Time (frames)')
ax.set_ylabel('Mel frequency bins')

fig.tight_layout()

# %% [markdown]
# # SPEC Augmentation
# Time and Frequency Masking!
#
# fREQUENCY mASK: Randomly Mask out a range of consecutive frequencies by adding horizonatal bars to our spectro gram
#
# Time Mask: Randomly block out ranges of time from the spectrogram by using vertical bars.
#
# We do this to prevent voerfitting and to help the model generalize better. The masked sections get replaced with a mean value :0 Which is pretty cool!!

# %%
spec.shape
# ..., number of mels, number of steps (time)
# Documentation literally says the first index is '...'
# Out:
# torch.Size([1, 64, 258])

# %%
# Defaulting to 10% and only one mask until we deiscuss what would 
# be most optional :)
def spec_mask(spec, max_mask_pct=0.1, num_freq_masks=1, num_time_masks=1):
    _, num_mels, num_steps = spec.shape
    
    # Get the average to replace the blocked zones
    mask_val = spec.mean()
    augment_spec = spec
    
    # Add frquency mask- will look like a horizonal bar
    freq_mask_param = max_mask_pct * num_mels
    for _ in range(num_freq_masks):
        augment_spec = torchaudio.transforms.FrequencyMasking(freq_mask_param)(augment_spec, mask_val)

    # Add time mask- will look like a vertical bar
    time_mask_param = max_mask_pct * num_steps
    for _ in range(num_time_masks):
        augment_spec = torchaudio.transforms.TimeMasking(time_mask_param)(augment_spec,mask_val)

    return augment_spec

# %% [markdown]
# ## Before Masking

# %%
spec = spectrogram(audio_files[1])
waveform, sr = audio_files[1]
fig, axs = plt.subplots(2, 1)

waveform = waveform.numpy()
num_channels, num_frames = waveform.shape
time_axis = torch.arange(0, num_frames) / sr

ax = axs[0]
ax.plot(time_axis, waveform[0], linewidth=1)
ax.grid(True)
ax.set_xlim([0, time_axis[-1]])
ax.set_title("Original Waveform")

s_spec = spec.squeeze().numpy()

ax = axs[1]
ax.imshow(s_spec, aspect='auto', origin='lower')
ax.set_title("Spectrogram")
ax.set_xlabel('Time (frames)')
ax.set_ylabel('Mel frequency bins')

fig.tight_layout()

# %% [markdown]
# ## After Masking

# %%
spec = spec_mask(spec)

# %%
waveform, sr = audio_files[1]
fig, axs = plt.subplots(2, 1)

waveform = waveform.numpy()
num_channels, num_frames = waveform.shape
time_axis = torch.arange(0, num_frames) / sr

ax = axs[0]
ax.plot(time_axis, waveform[0], linewidth=1)
ax.grid(True)
ax.set_xlim([0, time_axis[-1]])
ax.set_title("Original Waveform")

s_spec = spec.squeeze().numpy()

ax = axs[1]
ax.imshow(s_spec, aspect='auto', origin='lower')
ax.set_title("Spectrogram")
ax.set_xlabel('Time (frames)')
ax.set_ylabel('Mel frequency bins')

fig.tight_layout()

# %% [markdown]
# # Data Loader for Model
# - dataset Object that tranforms the audio- preping each data item
# - DataLoader from torch- to fecth the sata items and packages them to batches

# %%
# Group together audio opening function as well as audio transformation functions into a convenient class
class AudioFuncs():
    
    def open_audio(audio_file):
        signal, sample_rate = torchaudio.load(audio_file)
        return signal, sample_rate


    # Resample takes in audio file (aud) and desired sample rate (newsr) and ensures they match
    def resample(aud, newsr):
        signal, sr = aud

        if (sr == newsr):
            return aud
            
        # Resample channel
        re_signal = torchaudio.transforms.Resample(sr, newsr)(signal[:1,:])
    
        return ((re_signal, newsr))


    # Resize audio to be of specific time length (max_ms)
    def resize(aud, max_ms):
        signal, sample_rate = aud
        num_rows, signal_len = signal.shape

        # calculate what would make audio max_ms long
        max_len = sample_rate//1000 * max_ms

        if (signal_len > max_len):
            # Truncate signal
            signal = signal[:,:max_len]

        elif (signal_len < max_len):
            # Pad audio with silence instead. At beginning and end.
            pad_begin_len = random.randint(0, max_len - signal_len)
            pad_end_len = max_len - signal_len - pad_begin_len

            # Pad with 0s
            pad_begin = torch.zeros((num_rows, pad_begin_len))
            pad_end = torch.zeros((num_rows, pad_end_len))

            signal = torch.cat((pad_begin, signal, pad_end), 1)
        
        return (signal, sample_rate)
    
    # Rechannel audio
    def rechannel(audio, max_channels):
        
        signal, sr = audio

        # Verify audio isn't already correct number of channels 
        if (signal.shape[0] == max_channels):
            return audio
        
        # If audio channels > max_channels -> Reduce channels to max_channels
        if (signal.shape[0] > max_channels):
            new_signal = signal[:max_channels, :]
            
        else:
             # If audio channels < max_channels -> Add extra channels to reach max_channels
            num_current_channels = signal.shape[0]
            num_channels_to_add = max_channels - num_current_channels
            
            # Calculate full duplications and the remaining channels needed
            full_duplications = num_channels_to_add // num_current_channels
            remaining_channels = num_channels_to_add % num_current_channels

            # Duplicate the signal for full duplications
            new_signal = torch.cat([signal] * (full_duplications + 1), dim=0)

            # Add the remaining channels (if any) by slicing from the original signal
            if remaining_channels > 0:
                new_signal = torch.cat([new_signal, signal[:remaining_channels, :]], dim=0)

        return (new_signal[:max_channels, :], sr)


    # Creates spectrogram for given audio sample with specified mel bins and Fourier transformations.
    def spectrogram(audio, n_mels=128, n_fft=1024, hop_len=None):
        signal, sample_rate = audio
        top_db = 80

        # spectrogram shape is [channel, n_mels, time]
        spec = torchaudio.transforms.MelSpectrogram(sample_rate, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(signal)

        # Convert to decibels 
        spec = torchaudio.transforms.AmplitudeToDB(top_db=top_db)(spec)
        return spec
    

    # Visualize given spectrogram (spec) with matplotlib
    def plot_spectrogram(spec, title='Spectrogram'):
        # Convert the tensor to a numpy array and squeeze to 2D
        spec = spec.squeeze().numpy()

        plt.figure(figsize=(10, 4))
        plt.imshow(spec, aspect='auto', origin='lower')
        plt.colorbar()
        plt.title(title)
        plt.xlabel('Time (frames)')
        plt.ylabel('Mel frequency bins')
        return plt
    

    # Mask a percentage of the given spectrogram with averaging data to in theory reduce overfitting when training data. 
    # Defaulting to 10% and only one mask until we deiscuss what would be most optional for generalizing :)
    def spec_mask(spec, max_mask_pct=0.1, num_freq_masks=1, num_time_masks=1):
        _, num_mels, num_steps = spec.shape
        
        # Get the average to replace the blocked zones
        mask_val = spec.mean()
        augment_spec = spec
        
        # Add frquency mask- will look like a horizonal bar
        freq_mask_param = max_mask_pct * num_mels
        for _ in range(num_freq_masks):
            augment_spec = torchaudio.transforms.FrequencyMasking(freq_mask_param)(augment_spec, mask_val)

        # Add time mask- will look like a vertical bar
        time_mask_param = max_mask_pct * num_steps
        for _ in range(num_time_masks):
            augment_spec = torchaudio.transforms.TimeMasking(time_mask_param)(augment_spec,mask_val)

        return augment_spec

# %% [markdown]
# ### Test all custom preprocessing funcs

# %%
# Using Open Audio, for now we're just using aloe
audio_f = df[df['label'].isin(["aloe", "burger"])]['relative_path']
success = 0
fail = 0

fp = f"{os.getcwd()}\{audio_f[1]}"
aud = AudioFuncs.open_audio(fp)
print(aud)

        
# Tranformations for Audio
reaud = AudioFuncs.resample(aud, 44100)
rechan = AudioFuncs.rechannel(reaud, 1)
dur_aud = AudioFuncs.resize(rechan, 3000)

# Create and Transform Spectrogram
sgram = AudioFuncs.spectrogram(dur_aud, n_mels=64, n_fft=1024, hop_len=None)
s_spec = sgram.squeeze().numpy()

fig, axs = plt.subplots(2, 1)

num_channels, num_frames = waveform.shape
time_axis = torch.arange(0, num_frames) / sr


ax = axs[0]
ax.imshow(s_spec, aspect='auto', origin='lower')
ax.set_title("Spectrogram Aloe")
ax.set_xlabel('Time (frames)')
ax.set_ylabel('Mel frequency bins')





fp = f"{os.getcwd()}\{audio_f[1130]}"
aud = AudioFuncs.open_audio(fp) 
print(aud)

# Tranformations for Audio
reaud = AudioFuncs.resample(aud, 44100)
rechan = AudioFuncs.rechannel(reaud, 1)
dur_aud = AudioFuncs.resize(rechan, 3000)

# Create and Transform Spectrogram
sgram = AudioFuncs.spectrogram(dur_aud, n_mels=64, n_fft=1024, hop_len=None)
s_spec = sgram.squeeze().numpy()

ax = axs[1]
ax.imshow(s_spec, aspect='auto', origin='lower')
ax.set_title("Spectrogram Burger")
ax.set_xlabel('Time (frames)')
ax.set_ylabel('Mel frequency bins')

fig.tight_layout()
# Out:
# (tensor([[-0.0504, -0.0366, -0.0256,  ...,  0.0118,  0.0137,  0.0134]]), 44100)
# (tensor([[ 0.0135,  0.0133,  0.0109,  ..., -0.0392, -0.0382, -0.0388]]), 44100)

# %% [markdown]
# ### Custom Dataloader

# %%
class FoodAudioDS(Dataset):
    def __init__(self, df, dir_path, transform=None, target_transform=None):
        self.df = df
        self.dir_path = dir_path
        #self.transform = transform
        #self.target_transform = target_transform

        self.duration = 3000
        self.sample_rate = 44100
        self.channel = 1

    def __len__(self):
        return len(self.df)  

    def __getitem__(self, idx):

        # Get the Audio file location- using curr directory path and then files
        # relative path

        audio_file = self.dir_path + self.df.loc[idx, 'relative_path']
        
        # Get the Class ID
        class_id = self.df.loc[idx, 'classID']

        aud = AudioFuncs.open_audio(audio_file)
        
        # Tranformations for Audio
        reaud = AudioFuncs.resample(aud, self.sample_rate)
        rechan = AudioFuncs.rechannel(reaud, self.channel)
        dur_aud = AudioFuncs.resize(rechan, self.duration)

        # Create and Transform Spectrogram
        sgram = AudioFuncs.spectrogram(dur_aud, n_mels=64, n_fft=1024, hop_len=None)
        #sgram = AudioFuncs.spec_mask(sgram, max_mask_pct=0.1, num_freq_masks=1, num_time_masks=1)

        # Return spectrogram and classID
        return sgram, class_id
    
    def group_by(self, idx, column):
        return df.loc[idx][column]

# %% [markdown]
# ## CNN Model
# chose not to utilize dropout or normalization for final result

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

class CNN_Model(nn.Module):
    def __init__(self, num_classes=20):
        super().__init__()
        self.conv1=nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32,kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))
            
        )
        self.conv2=nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            
            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)),
            nn.Dropout(0.5)
        )
        self.conv3=nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128,kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            
            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))
        )
        self.conv4=nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256,kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Dropout(0.5) 
        )
        self.flatten=nn.Flatten()
        self.fc1=nn.Sequential(
            nn.Linear(256, 128),  # Reduced feature dimensions
            nn.ReLU(),
        )
        self.fc2 = nn.Linear(128, num_classes)
    
    def forward(self, x: torch.Tensor):
            x = self.conv1(x)
            x = self.conv2(x)
            x = self.conv3(x)
            x = self.conv4(x)
            x = self.flatten(x)
            x = self.fc1(x)
            try:
                x = self.fc2(x)
            except Exception as e:
                print(f"Error : Linear block should take support shape of {x.shape} for in_features.")
            return x

                
food_model = CNN_Model()

if torch.cuda.is_available():
     food_model.cuda()

print("Model summary : ")
print(summary(food_model, (1, 64, 258)))
# Out:
# Model summary :
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 32, 64, 258]             320
#               ReLU-2          [-1, 32, 64, 258]               0
#        BatchNorm2d-3          [-1, 32, 64, 258]              64
#          MaxPool2d-4          [-1, 32, 32, 129]               0
#             Conv2d-5          [-1, 64, 32, 129]          18,496
#               ReLU-6          [-1, 64, 32, 129]               0
#        BatchNorm2d-7          [-1, 64, 32, 129]             128
#          MaxPool2d-8           [-1, 64, 16, 64]               0
#            Dropout-9           [-1, 64, 16, 64]               0
#            Conv2d-10          [-1, 128, 16, 64]          73,856
#              ReLU-11          [-1, 128, 16, 64]               0
#       BatchNorm2d-12          [-1, 128, 16, 64]             256
#         MaxPool2d-13           [-1, 128, 8, 32]               0
#            Conv2d-14           [-1, 256, 8, 32]         295,168
#              ReLU-15           [-1, 256, 8, 32]               0
#       BatchNorm2d-16           [-1, 256, 8, 32]             512
# AdaptiveAvgPool2d-17            [-1, 256, 1, 1]               0
#           Dropout-18            [-1, 256, 1, 1]               0
#           Flatten-19                  [-1, 256]               0
#            Linear-20                  [-1, 128]          32,896
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 20]           2,580
# ================================================================
# Total params: 424,276
# Trainable params: 424,276
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 24.91
# Params size (MB): 1.62
# Estimated Total Size (MB): 26.59
# ----------------------------------------------------------------
# None

# %% [markdown]
# ## Code for training model

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sn

def train_and_plot(model, train_loader, val_loader, num_epoch):
    print("Initializing training process...")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Compute class weights
    class_counts = [546, 595, 499, 806, 660, 719, 290, 292, 644, 579, 678, 727, 442, 411, 872, 609, 488, 501, 278, 504]  # Replace with your actual counts
    total_samples = sum(class_counts)
    class_weights = torch.tensor([total_samples / count for count in class_counts]).to(device)


    # Loss Function, Optimizer
    criterion = nn.CrossEntropyLoss(class_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01,
                                                    steps_per_epoch=len(train_loader),
                                                    epochs=num_epoch,
                                                    anneal_strategy='cos')

    train_losses = []
    train_accuracies = []
    val_accuracies = []
    lrs = []

    for epoch in range(num_epoch):
        print(f"Epoch {epoch + 1}/{num_epoch}...")
        running_loss = 0.0
        correct_prediction = 0
        total_prediction = 0

        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            # Move data to device
            inputs, labels = data.to(device), target.to(device)

            # Normalize the inputs
            inputs = (inputs - inputs.mean(dim=[0, 2, 3], keepdim=True)) / inputs.std(dim=[0, 2, 3], keepdim=True)

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            # Collect loss
            running_loss += loss.item()

            # Calculate accuracy
            _, prediction = torch.max(outputs, 1)
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]

            # Collect learning rate
            lrs.append(optimizer.param_groups[0]['lr'])

            if ((batch_idx + 1) % 50 == 0):
                print('[Epoch: %d, Batch_Idx: %d, Accuracy: %.3f] loss: %.3f' % (epoch + 1, batch_idx + 1, correct_prediction / total_prediction, running_loss / (batch_idx + 1)))

        # Calculate metrics for this epoch
        avg_loss = running_loss / len(train_loader)
        train_accuracy = correct_prediction / total_prediction
        val_accuracy, y_test, y_pred = compute_accuracy(model, val_loader)

        # Generate confusion matrix
        plot_confusion_matrix(y_test, y_pred, class_labels, epoch + 1)

        train_losses.append(avg_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch + 1} complete. Loss: {avg_loss:.2f}, Train Accuracy: {train_accuracy:.2f}, Val Accuracy: {val_accuracy:.2f}")

    print("Training process complete!")

    # Plot the results
    plot_training_progress(train_losses, train_accuracies, val_accuracies, num_epoch)

# Create a Confusion Matrix of the predictions versus the true results
def plot_confusion_matrix(y_test, predictions, food_categories, epoch):
    conf_matrix = confusion_matrix(y_test, predictions)
    conf_matrix_norm = confusion_matrix(y_test, predictions,normalize='true')

    # set labels for matrix axes from emotions
    food_list = food_categories
    food_name = [food for food in food_list]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=food_name, columns=food_name)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=food_name, columns=food_name)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title(f'Confusion Matrix for Epoch {epoch}')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 10}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, fmt='.2f', annot=True, annot_kws={"size": 7}) #annot_kws is value font

    plt.show()

def compute_accuracy(model, data_loader):
    model.eval()
    correct_prediction = 0
    total_prediction = 0
    y_test = []
    y_pred = []

    with torch.no_grad():
        for data in data_loader:
            inputs, labels = data[0].to(torch.device("cuda" if torch.cuda.is_available() else "cpu")), data[1].to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
            
            # Normalize inputs
            inputs = (inputs - inputs.mean(dim=[0, 2, 3], keepdim=True)) / inputs.std(dim=[0, 2, 3], keepdim=True)

            # Get predictions
            outputs = model(inputs)
            _, prediction = torch.max(outputs, 1)

            y_test.extend(labels.cpu().numpy())
            y_pred.extend(prediction.cpu().numpy())

            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]

    return correct_prediction / total_prediction, y_test, y_pred


def plot_training_progress(train_losses, train_accuracies, val_accuracies, num_epochs):
    epochs = range(1, num_epochs + 1)

    plt.figure(figsize=(14, 6))

    # Loss Plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training Loss Over Epochs')
    plt.legend()
    plt.grid()

    # Accuracy Plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 20 way classification
#
# Comparing each class accuracy against the 19 others.
# We also look at 'Uniform Holdout' alongside 'Group Holdout' as methods of splitting the data between training, validation, and test.

# %%
def train_and_evaluate(model, train_loader, val_loader, num_epochs, class_labels):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    #loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, 
                                                    steps_per_epoch=len(train_loader), 
                                                    epochs=num_epochs)

    # metrics!!
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        # start of the loop
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            # forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            # calculate prediction and loss metrics
            running_loss += loss.item()
            _, predictions = torch.max(outputs, 1)
            correct_predictions += (predictions == labels).sum().item()
            total_predictions += labels.size(0)

        train_accuracy = correct_predictions / total_predictions
        train_accuracies.append(train_accuracy)

        # validate loop
        val_accuracy = evaluate(model, val_loader, device)
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {running_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Accuracy: {val_accuracy:.4f}")

    # Plot accuracy
    plot_accuracies(train_accuracies, val_accuracies, num_epochs)

def evaluate(model, data_loader, device):
    model.eval()
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        # loop through validation data points and pass them into the model
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            correct_predictions += (predictions == labels).sum().item()
            total_predictions += labels.size(0)

    return correct_predictions / total_predictions

def plot_accuracies(train_accuracies, val_accuracies, num_epochs):
    import matplotlib.pyplot as plt

    plt.figure(figsize=(10, 5))
    plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### Testing and data visualization functions

# %%
from sklearn.metrics import confusion_matrix
from torcheval.metrics.functional.classification import multiclass_recall
import seaborn as sn

def test_model(model, test_loader, class_labels):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())

    # Compute accuracy
    accuracy = sum(np.array(y_true) == np.array(y_pred)) / (len(y_true) + len(y_pred))
    print(f"Test Accuracy: {accuracy:.4f}")

    # Computer recall
    recall = multiclass_recall(torch.tensor(y_pred), torch.tensor(y_true), num_classes=20)
    print(f"Test Recall: {recall:.4f}")

    # conf Matrix
    plot_confusion_matrix(y_true, y_pred, class_labels)

def plot_confusion_matrix(y_test, predictions, food_categories):
    conf_matrix = confusion_matrix(y_test, predictions, labels=range(len(food_categories)))
    conf_matrix_norm = confusion_matrix(y_test, predictions, labels=range(len(food_categories)), normalize='true')

    # set labels for matrix axes from emotions
    food_list = food_categories
    food_name = [food for food in food_list]

    # make a confusion matrix with labels
    confmatrix_df = pd.DataFrame(conf_matrix, index=food_name, columns=food_name)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=food_name, columns=food_name)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1) 
    plt.subplot(1,2,1)
    plt.title(f'Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 10}) 
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, fmt='.2f', annot=True, annot_kws={"size": 7})

    plt.show()

# %% [markdown]
# #### Uniform Split

# %%
# Path and dataset initialization
dir_path = os.getcwd()
food_ds = FoodAudioDS(df, dir_path)

unique_labels = df['label'].unique()
assert len(unique_labels) == 20, "Dataset must contain exactly 20 classes!"

# Map labels to index
label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
df['label_index'] = df['label'].map(label_to_index)

# Split data into train, validation, and test sets (70%, 20%, 10%)
num_items = len(food_ds)
num_train_data = round(num_items * 0.7)
num_val_data = round(num_items * 0.2)
num_test_data = num_items - num_train_data - num_val_data

# Random split with generator for repro- uhhh 
g1 = torch.Generator().manual_seed(42) 
train_ds, val_ds, test_ds = random_split(food_ds, [num_train_data, num_val_data, num_test_data], generator=g1)

train_dl = DataLoader(train_ds, batch_size=16, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=16, shuffle=False)
test_dl = DataLoader(test_ds, batch_size=16, shuffle=False)

print(f"Training set: {len(train_ds)} samples")
print(f"Validation set: {len(val_ds)} samples")
print(f"Test set: {len(test_ds)} samples")

# train
train_and_evaluate(food_model, train_dl, val_dl, num_epochs=10, class_labels=unique_labels)

# test
test_model(food_model, test_dl, class_labels=unique_labels)
# Out:
# Training set: 7798 samples
# Validation set: 2228 samples
# Test set: 1114 samples
# Epoch 1/10, Loss: 1131.4754, Train Accuracy: 0.2776, Val Accuracy: 0.3259
# Epoch 2/10, Loss: 901.5870, Train Accuracy: 0.4136, Val Accuracy: 0.4901
# Epoch 3/10, Loss: 822.5982, Train Accuracy: 0.4694, Val Accuracy: 0.3855
# Epoch 4/10, Loss: 741.2240, Train Accuracy: 0.5315, Val Accuracy: 0.6185
# Epoch 5/10, Loss: 625.7715, Train Accuracy: 0.5976, Val Accuracy: 0.6499
# Epoch 6/10, Loss: 520.1152, Train Accuracy: 0.6570, Val Accuracy: 0.6854
# Epoch 7/10, Loss: 422.7711, Train Accuracy: 0.7139, Val Accuracy: 0.8196
# Epoch 8/10, Loss: 317.3048, Train Accuracy: 0.7801, Val Accuracy: 0.8586
# Epoch 9/10, Loss: 250.3081, Train Accuracy: 0.8288, Val Accuracy: 0.8869
# Epoch 10/10, Loss: 216.5320, Train Accuracy: 0.8541, Val Accuracy: 0.8864
# Test Accuracy: 0.4439
# Test Recall: 0.8878

# %% [markdown]
# #### Grouped Split

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], va = 'center')
from sklearn.model_selection import GroupShuffleSplit
from torch.utils.data import Subset

unique_labels = df['label'].unique()
assert len(unique_labels) == 20, "Dataset must contain exactly 20 classes!"

plt.figure(figsize=(10,10))
plt.barh(food_categories, df['label'].value_counts())

# Group foods by video
groups = [food_ds.group_by(i,'video') for i in range(len(food_ds))]  # Replace 'speaker_id' with the correct field

# Grouped split into training (70%), validation (20%), and test (10%)
gss = GroupShuffleSplit(n_splits=1, train_size=0.7, test_size=0.3, random_state=42)
train_idx, temp_idx = next(gss.split(range(len(food_ds)), groups=groups))

val_test_groups = [groups[i] for i in temp_idx]
gss_val_test = GroupShuffleSplit(n_splits=1, train_size=0.67, test_size=0.33, random_state=42)
val_idx, test_idx = next(gss_val_test.split(temp_idx, groups=val_test_groups))

# subsets!!
train_ds = Subset(food_ds, train_idx)
val_ds = Subset(food_ds, val_idx)
test_ds = Subset(food_ds, test_idx)

# DataLoader initialization
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=16, shuffle=False)
test_dl = DataLoader(test_ds, batch_size=16, shuffle=False)

print(f"Training set: {len(train_ds)} samples")
print(f"Validation set: {len(val_ds)} samples")
print(f"Test set: {len(test_ds)} samples")

# Train the model
train_and_evaluate(food_model, train_dl, val_dl, num_epochs=10, class_labels=unique_labels)

# Test the model
test_model(food_model, test_dl, class_labels=unique_labels)
# Out:
# Training set: 7356 samples
# Validation set: 2666 samples
# Test set: 1118 samples
# Epoch 1/10, Loss: 230.5048, Train Accuracy: 0.8363, Val Accuracy: 0.9250
# Epoch 2/10, Loss: 292.6202, Train Accuracy: 0.7965, Val Accuracy: 0.8335
# Epoch 3/10, Loss: 392.5982, Train Accuracy: 0.7327, Val Accuracy: 0.6395
# Epoch 4/10, Loss: 384.4061, Train Accuracy: 0.7443, Val Accuracy: 0.8331
# Epoch 5/10, Loss: 305.5722, Train Accuracy: 0.7912, Val Accuracy: 0.7689
# Epoch 6/10, Loss: 229.1106, Train Accuracy: 0.8427, Val Accuracy: 0.8203
# Epoch 7/10, Loss: 167.6335, Train Accuracy: 0.8832, Val Accuracy: 0.8620
# Epoch 8/10, Loss: 110.7364, Train Accuracy: 0.9187, Val Accuracy: 0.8807
# Epoch 9/10, Loss: 82.3086, Train Accuracy: 0.9414, Val Accuracy: 0.8815
# Epoch 10/10, Loss: 69.4435, Train Accuracy: 0.9500, Val Accuracy: 0.8706
# Test Accuracy: 0.4445
# Test Recall: 0.8891

# %% [markdown]
# ### Pairwise Evaluation

# %%
# Create a second dataloader
class FoodAudioPairDS(Dataset):
    def __init__(self, df, dir_path):
        self.df = df
        self.dir_path = dir_path
        self.cache = {}

        self.duration = 3000
        self.sample_rate = 44100
        self.channel = 1

    def __len__(self):
        return len(self.df)  

    def __getitem__(self, idx):
        if idx in self.cache:
            sgram = AudioFuncs.spec_mask(self.cache[idx][0], max_mask_pct=0.1, num_freq_masks=1, num_time_masks=1)
            return sgram,self.cache[idx][1]

        # Get the Audio file location- using curr directory path and then files
        # relative path

        audio_file = self.dir_path + self.df.loc[idx, 'relative_path']
        
        # Get the Class ID
        class_id = self.df.loc[idx, 'binary_label']

        aud = AudioFuncs.open_audio(audio_file)
        
        # Tranformations for Audio
        reaud = AudioFuncs.resample(aud, self.sample_rate)
        rechan = AudioFuncs.rechannel(reaud, self.channel)
        dur_aud = AudioFuncs.resize(rechan, self.duration)

        # Create and Transform Spectrogram
        sgram = AudioFuncs.spectrogram(dur_aud, n_mels=64, n_fft=1024, hop_len=None)
        self.cache[idx] = (sgram, class_id)
        sgram = AudioFuncs.spec_mask(sgram, max_mask_pct=0.1, num_freq_masks=1, num_time_masks=1)

        # Return spectrogram and classID
        return sgram, class_id
    
    def group_by(self, idx, column):
        return df.loc[idx][column]

# %%
def get_pairwise_dataset(df, label1, label2, dir_path):
   # Filter the dataset for the two labels
    pairwise_df = df[df['label'].isin([label1, label2])].copy()

    # Map labels to binary values: label1 -> 0, label2 -> 1
    label_map = {label1: 0, label2: 1}
    pairwise_df['binary_label'] = pairwise_df['label'].map(label_map)

    # Extract group information (e.g., speaker_id or session_id)
    groups = pairwise_df['video'].tolist()  

    # Create the pairwise dataset
    pairwise_ds = FoodAudioPairDS(pairwise_df, dir_path)

    return pairwise_df, pairwise_ds, groups

def grouped_split(df, pairwise, pairwise_ds, groups):
    train_idx, test_idx, val_idx = [], [], []

    for label in pairwise:
        # Filter rows for the current label
        label_df = df[df['label'] == label]
        
        # Use 'video' column as the grouping variable
        groups = label_df['video'].tolist()

        # Perform grouped split
        gss = GroupShuffleSplit(n_splits=1, test_size=0.1, train_size=0.7, random_state=42)
        label_train_idx, label_val_idx = next(gss.split(label_df, groups=groups))

        # Append the global indices to train and validation lists
        train_idx.extend(label_df.iloc[label_train_idx].index.tolist())
        val_idx.extend(label_df.iloc[label_val_idx].index.tolist())
        test_idx = list(set(label_df.index) - set(train_idx) - set(val_idx))
    
    
    train_ds = Subset(pairwise_ds, train_idx)
    test_ds = Subset(pairwise_ds, test_idx)

    # Test set (use remaining data not in train or val for test)
    val_ds = Subset(pairwise_ds, val_idx)

    # DataLoader initialization
    train_dl = DataLoader(train_ds, batch_size=16, shuffle=True)
    val_dl = DataLoader(val_ds, batch_size=16, shuffle=False)
    test_dl = DataLoader(test_ds, batch_size=16, shuffle=False)
    
    print(f"Training set: {len(train_ds)} samples")
    print(f"Validation set: {len(val_ds)} samples")
    print(f"Test set: {len(test_ds)} samples")
    print("=====================================\n")

    return train_dl, val_dl, test_dl


def train_and_evaluate_pairwise(model, train_loader, val_loader, num_epochs):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()  # Use binary labels (0, 1) but still apply CrossEntropyLoss
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer, max_lr=0.01, steps_per_epoch=len(train_loader), epochs=num_epochs,
        anneal_strategy='cos'
    )

    # metrics!!
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}...")
        # Training loop
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0

        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(torch.device("cuda")), labels.to(device)

            #assert inputs.device == device, "Inputs are not on the correct device!"
            #assert labels.device == device, "Labels are not on the correct device!"

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            # Metrics
            running_loss += loss.item()


            _, predictions = torch.max(outputs, 1)
            correct_predictions += (predictions == labels).sum().item()
            total_predictions += predictions.shape[0]

            #print('[Epoch: %d, Batch_Idx: %d, Accuracy: %.3f] loss: %.3f' % (epoch + 1, batch_idx + 1, correct_predictions / total_predictions, running_loss / (batch_idx + 1)))

        train_accuracy = correct_predictions / total_predictions

        # Validation loop
        val_accuracy = evaluate(model, val_loader, device)
        # print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {running_loss/len(train_loader):.4f}, Train Accuracy: {train_accuracy:.4f}, Val Accuracy: {val_accuracy:.4f}")

    return train_accuracy, val_accuracy


# Evaluate model on test set
def evaluate(model, data_loader, device):
    model.eval()
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            correct_predictions += (predictions == labels).sum().item()
            total_predictions += labels.size(0)

    return correct_predictions / total_predictions


def pairwise_classification_with_groups(df, dir_path, num_epochs):
    labels = df['label'].unique()
    results = {}

    unique_labels = df['label'].unique()
    assert len(unique_labels) == 20, "Dataset must contain exactly 20 classes!"

    pairwise_model = CNN_Model(num_classes=2)
    
    for label1, label2 in combinations(labels, 2):
        print(f"Training pairwise model for: {label1} vs {label2}")

        # Create pairwise dataset with groups
        pairwise_df, pairwise_ds, groups = get_pairwise_dataset(df, label1, label2, dir_path)
        #print("=======Pairewise Dataframe===============")
        

        # Perform grouped split
        train_dl, val_dl, test_dl = grouped_split(df, [label1, label2], pairwise_ds, groups)

        # Initialize a new model for each pair
        

        # Train and evaluate
        train_acc, val_acc = train_and_evaluate_pairwise(pairwise_model, train_dl, val_dl, num_epochs)

        # Test model
        test_acc = evaluate(pairwise_model, test_dl, torch.device("cuda" if torch.cuda.is_available() else "cpu"))

        # Save results
        results[(label1, label2)] = {
            "train_accuracy": train_acc,
            "val_accuracy": val_acc,
            "test_accuracy": test_acc
        }

        print(f"Results for {label1} vs {label2}: Train Accuracy = {train_acc:.4f}, Val Accuracy = {val_acc:.4f}, Test Accuracy = {test_acc:.4f}\n")

    return results

# %%
# Path and dataset initialization
dir_path = os.getcwd()
food_ds = FoodAudioDS(df, dir_path)

unique_labels = df['label'].unique()
assert len(unique_labels) == 20, "Dataset must contain exactly 20 classes!"


# Run pairwise classification with grouped splits
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results = pairwise_classification_with_groups(df, os.getcwd(), num_epochs=5)

# Print summary of results
for pair, metrics in results.items():
    print(f"Pair: {pair}, Train Accuracy: {metrics['train_accuracy']:.4f}, Val Accuracy: {metrics['val_accuracy']:.4f}, Test Accuracy: {metrics['test_accuracy']:.4f}")
# Out:
# Training pairwise model for: aloe vs burger
# Training set: 873 samples
# Validation set: 131 samples
# Test set: 64 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs burger: Train Accuracy = 0.9496, Val Accuracy = 0.9695, Test Accuracy = 0.9844
#
# Training pairwise model for: aloe vs cabbage
# Training set: 825 samples
# Validation set: 94 samples
# Test set: 53 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs cabbage: Train Accuracy = 0.9733, Val Accuracy = 0.9468, Test Accuracy = 0.6604
#
# Training pairwise model for: aloe vs candied_fruits
# Training set: 987 samples
# Validation set: 174 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs candied_fruits: Train Accuracy = 0.9666, Val Accuracy = 0.9828, Test Accuracy = 0.8729
#
# Training pairwise model for: aloe vs carrots
# Training set: 919 samples
# Validation set: 124 samples
# Test set: 90 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs carrots: Train Accuracy = 0.9728, Val Accuracy = 0.6452, Test Accuracy = 0.4111
#
# Training pairwise model for: aloe vs chips
# Training set: 942 samples
# Validation set: 114 samples
# Test set: 136 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs chips: Train Accuracy = 0.9745, Val Accuracy = 0.9825, Test Accuracy = 0.9191
#
# Training pairwise model for: aloe vs chocolate
# Training set: 616 samples
# Validation set: 82 samples
# Test set: 65 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs chocolate: Train Accuracy = 0.9594, Val Accuracy = 0.6341, Test Accuracy = 0.9231
#
# Training pairwise model for: aloe vs drinks
# Training set: 648 samples
# Validation set: 69 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs drinks: Train Accuracy = 0.9676, Val Accuracy = 0.8841, Test Accuracy = 0.9792
#
# Training pairwise model for: aloe vs fries
# Training set: 813 samples
# Validation set: 199 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs fries: Train Accuracy = 0.9569, Val Accuracy = 0.8191, Test Accuracy = 0.9810
#
# Training pairwise model for: aloe vs grapes
# Training set: 784 samples
# Validation set: 126 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs grapes: Train Accuracy = 0.9719, Val Accuracy = 0.4286, Test Accuracy = 0.5282
#
# Training pairwise model for: aloe vs gummies
# Training set: 889 samples
# Validation set: 170 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs gummies: Train Accuracy = 0.9786, Val Accuracy = 0.9059, Test Accuracy = 0.9783
#
# Training pairwise model for: aloe vs ice-cream
# Training set: 854 samples
# Validation set: 222 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs ice-cream: Train Accuracy = 0.9824, Val Accuracy = 0.9189, Test Accuracy = 0.9758
#
# Training pairwise model for: aloe vs jelly
# Training set: 768 samples
# Validation set: 40 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs jelly: Train Accuracy = 0.9557, Val Accuracy = 0.5750, Test Accuracy = 0.8972
#
# Training pairwise model for: aloe vs noodles
# Training set: 754 samples
# Validation set: 60 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs noodles: Train Accuracy = 0.9735, Val Accuracy = 0.8500, Test Accuracy = 0.9571
#
# Training pairwise model for: aloe vs pickles
# Training set: 1012 samples
# Validation set: 147 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs pickles: Train Accuracy = 0.9625, Val Accuracy = 0.8776, Test Accuracy = 0.7634
#
# Training pairwise model for: aloe vs pizza
# Training set: 858 samples
# Validation set: 140 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs pizza: Train Accuracy = 0.9848, Val Accuracy = 0.4286, Test Accuracy = 0.5357
#
# Training pairwise model for: aloe vs ribs
# Training set: 809 samples
# Validation set: 71 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs ribs: Train Accuracy = 0.9629, Val Accuracy = 0.8028, Test Accuracy = 1.0000
#
# Training pairwise model for: aloe vs salmon
# Training set: 757 samples
# Validation set: 115 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs salmon: Train Accuracy = 0.9736, Val Accuracy = 0.6783, Test Accuracy = 0.8235
#
# Training pairwise model for: aloe vs soup
# Training set: 624 samples
# Validation set: 70 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs soup: Train Accuracy = 0.9728, Val Accuracy = 0.6571, Test Accuracy = 0.9474
#
# Training pairwise model for: aloe vs wings
# Training set: 760 samples
# Validation set: 99 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for aloe vs wings: Train Accuracy = 0.9882, Val Accuracy = 0.9091, Test Accuracy = 0.9407
#
# Training pairwise model for: burger vs cabbage
# Training set: 812 samples
# Validation set: 165 samples
# Test set: 53 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs cabbage: Train Accuracy = 0.9667, Val Accuracy = 0.7939, Test Accuracy = 0.6226
#
# Training pairwise model for: burger vs candied_fruits
# Training set: 974 samples
# Validation set: 245 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs candied_fruits: Train Accuracy = 0.9805, Val Accuracy = 0.8694, Test Accuracy = 0.9322
#
# Training pairwise model for: burger vs carrots
# Training set: 906 samples
# Validation set: 195 samples
# Test set: 90 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs carrots: Train Accuracy = 0.9868, Val Accuracy = 0.8051, Test Accuracy = 0.4222
#
# Training pairwise model for: burger vs chips
# Training set: 929 samples
# Validation set: 185 samples
# Test set: 136 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs chips: Train Accuracy = 0.9752, Val Accuracy = 0.8378, Test Accuracy = 1.0000
#
# Training pairwise model for: burger vs chocolate
# Training set: 603 samples
# Validation set: 153 samples
# Test set: 65 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs chocolate: Train Accuracy = 0.9784, Val Accuracy = 0.8235, Test Accuracy = 1.0000
#
# Training pairwise model for: burger vs drinks
# Training set: 635 samples
# Validation set: 140 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs drinks: Train Accuracy = 0.9937, Val Accuracy = 0.8929, Test Accuracy = 0.9583
#
# Training pairwise model for: burger vs fries
# Training set: 800 samples
# Validation set: 270 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs fries: Train Accuracy = 0.9625, Val Accuracy = 0.8407, Test Accuracy = 0.9810
#
# Training pairwise model for: burger vs grapes
# Training set: 771 samples
# Validation set: 197 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs grapes: Train Accuracy = 0.9780, Val Accuracy = 0.8325, Test Accuracy = 0.5423
#
# Training pairwise model for: burger vs gummies
# Training set: 876 samples
# Validation set: 241 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs gummies: Train Accuracy = 0.9715, Val Accuracy = 0.8921, Test Accuracy = 1.0000
#
# Training pairwise model for: burger vs ice-cream
# Training set: 841 samples
# Validation set: 293 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs ice-cream: Train Accuracy = 0.9810, Val Accuracy = 0.9761, Test Accuracy = 0.9839
#
# Training pairwise model for: burger vs jelly
# Training set: 755 samples
# Validation set: 111 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs jelly: Train Accuracy = 0.9735, Val Accuracy = 0.8829, Test Accuracy = 0.8131
#
# Training pairwise model for: burger vs noodles
# Training set: 741 samples
# Validation set: 131 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs noodles: Train Accuracy = 0.9366, Val Accuracy = 0.7939, Test Accuracy = 0.9857
#
# Training pairwise model for: burger vs pickles
# Training set: 999 samples
# Validation set: 218 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs pickles: Train Accuracy = 0.9820, Val Accuracy = 0.8349, Test Accuracy = 0.8763
#
# Training pairwise model for: burger vs pizza
# Training set: 845 samples
# Validation set: 211 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs pizza: Train Accuracy = 0.9751, Val Accuracy = 0.6682, Test Accuracy = 0.6429
#
# Training pairwise model for: burger vs ribs
# Training set: 796 samples
# Validation set: 142 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs ribs: Train Accuracy = 0.9786, Val Accuracy = 0.4718, Test Accuracy = 0.8765
#
# Training pairwise model for: burger vs salmon
# Training set: 744 samples
# Validation set: 186 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs salmon: Train Accuracy = 0.9852, Val Accuracy = 0.5914, Test Accuracy = 0.8137
#
# Training pairwise model for: burger vs soup
# Training set: 611 samples
# Validation set: 141 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs soup: Train Accuracy = 0.9689, Val Accuracy = 0.4539, Test Accuracy = 1.0000
#
# Training pairwise model for: burger vs wings
# Training set: 747 samples
# Validation set: 170 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for burger vs wings: Train Accuracy = 0.9625, Val Accuracy = 0.5176, Test Accuracy = 0.9831
#
# Training pairwise model for: cabbage vs candied_fruits
# Training set: 926 samples
# Validation set: 208 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs candied_fruits: Train Accuracy = 0.9730, Val Accuracy = 0.7356, Test Accuracy = 0.6271
#
# Training pairwise model for: cabbage vs carrots
# Training set: 858 samples
# Validation set: 158 samples
# Test set: 90 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs carrots: Train Accuracy = 0.9662, Val Accuracy = 0.7722, Test Accuracy = 0.3556
#
# Training pairwise model for: cabbage vs chips
# Training set: 881 samples
# Validation set: 148 samples
# Test set: 136 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs chips: Train Accuracy = 0.9444, Val Accuracy = 0.8446, Test Accuracy = 0.9485
#
# Training pairwise model for: cabbage vs chocolate
# Training set: 555 samples
# Validation set: 116 samples
# Test set: 65 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs chocolate: Train Accuracy = 0.9856, Val Accuracy = 0.9828, Test Accuracy = 1.0000
#
# Training pairwise model for: cabbage vs drinks
# Training set: 587 samples
# Validation set: 103 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs drinks: Train Accuracy = 0.9813, Val Accuracy = 0.9709, Test Accuracy = 1.0000
#
# Training pairwise model for: cabbage vs fries
# Training set: 752 samples
# Validation set: 233 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs fries: Train Accuracy = 0.9561, Val Accuracy = 0.7940, Test Accuracy = 0.9810
#
# Training pairwise model for: cabbage vs grapes
# Training set: 723 samples
# Validation set: 160 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs grapes: Train Accuracy = 0.9779, Val Accuracy = 0.7625, Test Accuracy = 0.9859
#
# Training pairwise model for: cabbage vs gummies
# Training set: 828 samples
# Validation set: 204 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs gummies: Train Accuracy = 0.9891, Val Accuracy = 0.9706, Test Accuracy = 1.0000
#
# Training pairwise model for: cabbage vs ice-cream
# Training set: 793 samples
# Validation set: 256 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs ice-cream: Train Accuracy = 0.9899, Val Accuracy = 0.9180, Test Accuracy = 1.0000
#
# Training pairwise model for: cabbage vs jelly
# Training set: 707 samples
# Validation set: 74 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs jelly: Train Accuracy = 0.9844, Val Accuracy = 0.9730, Test Accuracy = 1.0000
#
# Training pairwise model for: cabbage vs noodles
# Training set: 693 samples
# Validation set: 94 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs noodles: Train Accuracy = 0.9870, Val Accuracy = 0.6596, Test Accuracy = 0.9714
#
# Training pairwise model for: cabbage vs pickles
# Training set: 951 samples
# Validation set: 181 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs pickles: Train Accuracy = 0.9832, Val Accuracy = 0.6188, Test Accuracy = 0.9731
#
# Training pairwise model for: cabbage vs pizza
# Training set: 797 samples
# Validation set: 174 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs pizza: Train Accuracy = 0.9737, Val Accuracy = 0.6092, Test Accuracy = 0.6190
#
# Training pairwise model for: cabbage vs ribs
# Training set: 748 samples
# Validation set: 105 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs ribs: Train Accuracy = 0.9853, Val Accuracy = 0.5143, Test Accuracy = 0.9877
#
# Training pairwise model for: cabbage vs salmon
# Training set: 696 samples
# Validation set: 149 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs salmon: Train Accuracy = 0.9914, Val Accuracy = 0.7651, Test Accuracy = 0.9804
#
# Training pairwise model for: cabbage vs soup
# Training set: 563 samples
# Validation set: 104 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs soup: Train Accuracy = 0.9805, Val Accuracy = 0.7212, Test Accuracy = 0.9474
#
# Training pairwise model for: cabbage vs wings
# Training set: 699 samples
# Validation set: 133 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for cabbage vs wings: Train Accuracy = 0.9671, Val Accuracy = 0.7293, Test Accuracy = 0.9915
#
# Training pairwise model for: candied_fruits vs carrots
# Training set: 1020 samples
# Validation set: 238 samples
# Test set: 90 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs carrots: Train Accuracy = 0.9725, Val Accuracy = 0.7815, Test Accuracy = 0.3444
#
# Training pairwise model for: candied_fruits vs chips
# Training set: 1043 samples
# Validation set: 228 samples
# Test set: 136 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs chips: Train Accuracy = 0.9789, Val Accuracy = 0.9912, Test Accuracy = 0.9559
#
# Training pairwise model for: candied_fruits vs chocolate
# Training set: 717 samples
# Validation set: 196 samples
# Test set: 65 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs chocolate: Train Accuracy = 0.9637, Val Accuracy = 0.9796, Test Accuracy = 1.0000
#
# Training pairwise model for: candied_fruits vs drinks
# Training set: 749 samples
# Validation set: 183 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs drinks: Train Accuracy = 0.9920, Val Accuracy = 0.9945, Test Accuracy = 1.0000
#
# Training pairwise model for: candied_fruits vs fries
# Training set: 914 samples
# Validation set: 313 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs fries: Train Accuracy = 0.9726, Val Accuracy = 0.8307, Test Accuracy = 0.8857
#
# Training pairwise model for: candied_fruits vs grapes
# Training set: 885 samples
# Validation set: 240 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs grapes: Train Accuracy = 0.9627, Val Accuracy = 0.9625, Test Accuracy = 0.4507
#
# Training pairwise model for: candied_fruits vs gummies
# Training set: 990 samples
# Validation set: 284 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs gummies: Train Accuracy = 0.9697, Val Accuracy = 0.9261, Test Accuracy = 0.9891
#
# Training pairwise model for: candied_fruits vs ice-cream
# Training set: 955 samples
# Validation set: 336 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs ice-cream: Train Accuracy = 0.9738, Val Accuracy = 0.7560, Test Accuracy = 1.0000
#
# Training pairwise model for: candied_fruits vs jelly
# Training set: 869 samples
# Validation set: 154 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs jelly: Train Accuracy = 0.9632, Val Accuracy = 0.9935, Test Accuracy = 0.9065
#
# Training pairwise model for: candied_fruits vs noodles
# Training set: 855 samples
# Validation set: 174 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs noodles: Train Accuracy = 0.9836, Val Accuracy = 0.9828, Test Accuracy = 0.8429
#
# Training pairwise model for: candied_fruits vs pickles
# Training set: 1113 samples
# Validation set: 261 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs pickles: Train Accuracy = 0.9802, Val Accuracy = 0.9617, Test Accuracy = 0.9032
#
# Training pairwise model for: candied_fruits vs pizza
# Training set: 959 samples
# Validation set: 254 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs pizza: Train Accuracy = 0.9604, Val Accuracy = 0.9646, Test Accuracy = 0.9881
#
# Training pairwise model for: candied_fruits vs ribs
# Training set: 910 samples
# Validation set: 185 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs ribs: Train Accuracy = 0.9615, Val Accuracy = 0.9784, Test Accuracy = 0.9012
#
# Training pairwise model for: candied_fruits vs salmon
# Training set: 858 samples
# Validation set: 229 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs salmon: Train Accuracy = 0.9942, Val Accuracy = 1.0000, Test Accuracy = 0.9412
#
# Training pairwise model for: candied_fruits vs soup
# Training set: 725 samples
# Validation set: 184 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs soup: Train Accuracy = 0.9903, Val Accuracy = 0.9728, Test Accuracy = 1.0000
#
# Training pairwise model for: candied_fruits vs wings
# Training set: 861 samples
# Validation set: 213 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for candied_fruits vs wings: Train Accuracy = 0.9628, Val Accuracy = 0.9202, Test Accuracy = 1.0000
#
# Training pairwise model for: carrots vs chips
# Training set: 975 samples
# Validation set: 178 samples
# Test set: 136 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs chips: Train Accuracy = 0.9446, Val Accuracy = 0.6685, Test Accuracy = 0.6397
#
# Training pairwise model for: carrots vs chocolate
# Training set: 649 samples
# Validation set: 146 samples
# Test set: 65 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs chocolate: Train Accuracy = 0.9399, Val Accuracy = 0.6781, Test Accuracy = 0.3385
#
# Training pairwise model for: carrots vs drinks
# Training set: 681 samples
# Validation set: 133 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs drinks: Train Accuracy = 0.9883, Val Accuracy = 0.6316, Test Accuracy = 0.8333
#
# Training pairwise model for: carrots vs fries
# Training set: 846 samples
# Validation set: 263 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs fries: Train Accuracy = 0.9894, Val Accuracy = 0.7795, Test Accuracy = 0.8952
#
# Training pairwise model for: carrots vs grapes
# Training set: 817 samples
# Validation set: 190 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs grapes: Train Accuracy = 0.9645, Val Accuracy = 0.5737, Test Accuracy = 0.5634
#
# Training pairwise model for: carrots vs gummies
# Training set: 922 samples
# Validation set: 234 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs gummies: Train Accuracy = 0.9816, Val Accuracy = 0.8248, Test Accuracy = 0.9891
#
# Training pairwise model for: carrots vs ice-cream
# Training set: 887 samples
# Validation set: 286 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs ice-cream: Train Accuracy = 0.9741, Val Accuracy = 0.8601, Test Accuracy = 0.8387
#
# Training pairwise model for: carrots vs jelly
# Training set: 801 samples
# Validation set: 104 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs jelly: Train Accuracy = 0.9775, Val Accuracy = 0.6731, Test Accuracy = 1.0000
#
# Training pairwise model for: carrots vs noodles
# Training set: 787 samples
# Validation set: 124 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs noodles: Train Accuracy = 0.9873, Val Accuracy = 0.7419, Test Accuracy = 0.7286
#
# Training pairwise model for: carrots vs pickles
# Training set: 1045 samples
# Validation set: 211 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs pickles: Train Accuracy = 0.9627, Val Accuracy = 0.7014, Test Accuracy = 0.8387
#
# Training pairwise model for: carrots vs pizza
# Training set: 891 samples
# Validation set: 204 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs pizza: Train Accuracy = 0.9764, Val Accuracy = 0.4755, Test Accuracy = 0.9167
#
# Training pairwise model for: carrots vs ribs
# Training set: 842 samples
# Validation set: 135 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs ribs: Train Accuracy = 0.9881, Val Accuracy = 0.7259, Test Accuracy = 1.0000
#
# Training pairwise model for: carrots vs salmon
# Training set: 790 samples
# Validation set: 179 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs salmon: Train Accuracy = 0.9848, Val Accuracy = 0.8324, Test Accuracy = 0.9216
#
# Training pairwise model for: carrots vs soup
# Training set: 657 samples
# Validation set: 134 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs soup: Train Accuracy = 0.9817, Val Accuracy = 0.6493, Test Accuracy = 0.9123
#
# Training pairwise model for: carrots vs wings
# Training set: 793 samples
# Validation set: 163 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for carrots vs wings: Train Accuracy = 0.9811, Val Accuracy = 0.7117, Test Accuracy = 0.8390
#
# Training pairwise model for: chips vs chocolate
# Training set: 672 samples
# Validation set: 136 samples
# Test set: 65 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs chocolate: Train Accuracy = 0.9732, Val Accuracy = 0.9926, Test Accuracy = 0.9385
#
# Training pairwise model for: chips vs drinks
# Training set: 704 samples
# Validation set: 123 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs drinks: Train Accuracy = 0.9872, Val Accuracy = 0.9837, Test Accuracy = 1.0000
#
# Training pairwise model for: chips vs fries
# Training set: 869 samples
# Validation set: 253 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs fries: Train Accuracy = 0.9436, Val Accuracy = 0.7984, Test Accuracy = 0.8095
#
# Training pairwise model for: chips vs grapes
# Training set: 840 samples
# Validation set: 180 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs grapes: Train Accuracy = 0.9702, Val Accuracy = 0.9556, Test Accuracy = 0.9577
#
# Training pairwise model for: chips vs gummies
# Training set: 945 samples
# Validation set: 224 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs gummies: Train Accuracy = 0.9810, Val Accuracy = 0.9598, Test Accuracy = 1.0000
#
# Training pairwise model for: chips vs ice-cream
# Training set: 910 samples
# Validation set: 276 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs ice-cream: Train Accuracy = 0.9890, Val Accuracy = 0.9855, Test Accuracy = 0.8952
#
# Training pairwise model for: chips vs jelly
# Training set: 824 samples
# Validation set: 94 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs jelly: Train Accuracy = 0.9867, Val Accuracy = 1.0000, Test Accuracy = 1.0000
#
# Training pairwise model for: chips vs noodles
# Training set: 810 samples
# Validation set: 114 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs noodles: Train Accuracy = 0.9889, Val Accuracy = 0.9035, Test Accuracy = 0.9000
#
# Training pairwise model for: chips vs pickles
# Training set: 1068 samples
# Validation set: 201 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs pickles: Train Accuracy = 0.9785, Val Accuracy = 0.9801, Test Accuracy = 0.9570
#
# Training pairwise model for: chips vs pizza
# Training set: 914 samples
# Validation set: 194 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs pizza: Train Accuracy = 0.9847, Val Accuracy = 0.4227, Test Accuracy = 0.6071
#
# Training pairwise model for: chips vs ribs
# Training set: 865 samples
# Validation set: 125 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs ribs: Train Accuracy = 0.9815, Val Accuracy = 0.9520, Test Accuracy = 1.0000
#
# Training pairwise model for: chips vs salmon
# Training set: 813 samples
# Validation set: 169 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs salmon: Train Accuracy = 0.9902, Val Accuracy = 0.9822, Test Accuracy = 0.9118
#
# Training pairwise model for: chips vs soup
# Training set: 680 samples
# Validation set: 124 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs soup: Train Accuracy = 0.9809, Val Accuracy = 0.9839, Test Accuracy = 0.9825
#
# Training pairwise model for: chips vs wings
# Training set: 816 samples
# Validation set: 153 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chips vs wings: Train Accuracy = 0.9755, Val Accuracy = 0.8758, Test Accuracy = 0.8898
#
# Training pairwise model for: chocolate vs drinks
# Training set: 378 samples
# Validation set: 91 samples
# Test set: 48 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs drinks: Train Accuracy = 0.9101, Val Accuracy = 0.5275, Test Accuracy = 0.5417
#
# Training pairwise model for: chocolate vs fries
# Training set: 543 samples
# Validation set: 221 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs fries: Train Accuracy = 0.9429, Val Accuracy = 0.6244, Test Accuracy = 0.8095
#
# Training pairwise model for: chocolate vs grapes
# Training set: 514 samples
# Validation set: 148 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs grapes: Train Accuracy = 0.9650, Val Accuracy = 0.7297, Test Accuracy = 0.5563
#
# Training pairwise model for: chocolate vs gummies
# Training set: 619 samples
# Validation set: 192 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs gummies: Train Accuracy = 0.9693, Val Accuracy = 0.6719, Test Accuracy = 1.0000
#
# Training pairwise model for: chocolate vs ice-cream
# Training set: 584 samples
# Validation set: 244 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs ice-cream: Train Accuracy = 0.9521, Val Accuracy = 0.8238, Test Accuracy = 0.8145
#
# Training pairwise model for: chocolate vs jelly
# Training set: 498 samples
# Validation set: 62 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs jelly: Train Accuracy = 0.9036, Val Accuracy = 0.1613, Test Accuracy = 1.0000
#
# Training pairwise model for: chocolate vs noodles
# Training set: 484 samples
# Validation set: 82 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs noodles: Train Accuracy = 0.9669, Val Accuracy = 0.7073, Test Accuracy = 0.3714
#
# Training pairwise model for: chocolate vs pickles
# Training set: 742 samples
# Validation set: 169 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs pickles: Train Accuracy = 0.9717, Val Accuracy = 0.6627, Test Accuracy = 0.9839
#
# Training pairwise model for: chocolate vs pizza
# Training set: 588 samples
# Validation set: 162 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs pizza: Train Accuracy = 0.9813, Val Accuracy = 0.4383, Test Accuracy = 1.0000
#
# Training pairwise model for: chocolate vs ribs
# Training set: 539 samples
# Validation set: 93 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs ribs: Train Accuracy = 0.9703, Val Accuracy = 0.4516, Test Accuracy = 0.9877
#
# Training pairwise model for: chocolate vs salmon
# Training set: 487 samples
# Validation set: 137 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs salmon: Train Accuracy = 0.9836, Val Accuracy = 0.5985, Test Accuracy = 0.8235
#
# Training pairwise model for: chocolate vs soup
# Training set: 354 samples
# Validation set: 92 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs soup: Train Accuracy = 0.9492, Val Accuracy = 0.4130, Test Accuracy = 1.0000
#
# Training pairwise model for: chocolate vs wings
# Training set: 490 samples
# Validation set: 121 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for chocolate vs wings: Train Accuracy = 0.9755, Val Accuracy = 0.6446, Test Accuracy = 0.9068
#
# Training pairwise model for: drinks vs fries
# Training set: 575 samples
# Validation set: 208 samples
# Test set: 105 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs fries: Train Accuracy = 0.9617, Val Accuracy = 0.8846, Test Accuracy = 0.9714
#
# Training pairwise model for: drinks vs grapes
# Training set: 546 samples
# Validation set: 135 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs grapes: Train Accuracy = 0.9689, Val Accuracy = 0.8370, Test Accuracy = 0.9718
#
# Training pairwise model for: drinks vs gummies
# Training set: 651 samples
# Validation set: 179 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs gummies: Train Accuracy = 0.9831, Val Accuracy = 0.9330, Test Accuracy = 1.0000
#
# Training pairwise model for: drinks vs ice-cream
# Training set: 616 samples
# Validation set: 231 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs ice-cream: Train Accuracy = 0.9838, Val Accuracy = 0.9654, Test Accuracy = 0.9919
#
# Training pairwise model for: drinks vs jelly
# Training set: 530 samples
# Validation set: 49 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs jelly: Train Accuracy = 0.9604, Val Accuracy = 0.8980, Test Accuracy = 1.0000
#
# Training pairwise model for: drinks vs noodles
# Training set: 516 samples
# Validation set: 69 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs noodles: Train Accuracy = 0.9903, Val Accuracy = 0.7826, Test Accuracy = 0.5857
#
# Training pairwise model for: drinks vs pickles
# Training set: 774 samples
# Validation set: 156 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs pickles: Train Accuracy = 0.9948, Val Accuracy = 1.0000, Test Accuracy = 0.9839
#
# Training pairwise model for: drinks vs pizza
# Training set: 620 samples
# Validation set: 149 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs pizza: Train Accuracy = 0.9968, Val Accuracy = 0.9933, Test Accuracy = 0.9881
#
# Training pairwise model for: drinks vs ribs
# Training set: 571 samples
# Validation set: 80 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs ribs: Train Accuracy = 0.9860, Val Accuracy = 0.7125, Test Accuracy = 0.9012
#
# Training pairwise model for: drinks vs salmon
# Training set: 519 samples
# Validation set: 124 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs salmon: Train Accuracy = 0.9711, Val Accuracy = 0.9355, Test Accuracy = 1.0000
#
# Training pairwise model for: drinks vs soup
# Training set: 386 samples
# Validation set: 79 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs soup: Train Accuracy = 0.9715, Val Accuracy = 0.5443, Test Accuracy = 0.8421
#
# Training pairwise model for: drinks vs wings
# Training set: 522 samples
# Validation set: 108 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for drinks vs wings: Train Accuracy = 0.9904, Val Accuracy = 0.9722, Test Accuracy = 0.9831
#
# Training pairwise model for: fries vs grapes
# Training set: 711 samples
# Validation set: 265 samples
# Test set: 142 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs grapes: Train Accuracy = 0.9142, Val Accuracy = 0.6868, Test Accuracy = 0.8732
#
# Training pairwise model for: fries vs gummies
# Training set: 816 samples
# Validation set: 309 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs gummies: Train Accuracy = 0.9730, Val Accuracy = 0.8317, Test Accuracy = 1.0000
#
# Training pairwise model for: fries vs ice-cream
# Training set: 781 samples
# Validation set: 361 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs ice-cream: Train Accuracy = 0.9641, Val Accuracy = 0.9806, Test Accuracy = 0.9597
#
# Training pairwise model for: fries vs jelly
# Training set: 695 samples
# Validation set: 179 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs jelly: Train Accuracy = 0.9640, Val Accuracy = 0.8268, Test Accuracy = 1.0000
#
# Training pairwise model for: fries vs noodles
# Training set: 681 samples
# Validation set: 199 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs noodles: Train Accuracy = 0.9633, Val Accuracy = 0.8291, Test Accuracy = 1.0000
#
# Training pairwise model for: fries vs pickles
# Training set: 939 samples
# Validation set: 286 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs pickles: Train Accuracy = 0.9691, Val Accuracy = 0.7587, Test Accuracy = 0.5054
#
# Training pairwise model for: fries vs pizza
# Training set: 785 samples
# Validation set: 279 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs pizza: Train Accuracy = 0.9427, Val Accuracy = 0.2975, Test Accuracy = 0.7024
#
# Training pairwise model for: fries vs ribs
# Training set: 736 samples
# Validation set: 210 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs ribs: Train Accuracy = 0.9538, Val Accuracy = 0.4333, Test Accuracy = 0.9877
#
# Training pairwise model for: fries vs salmon
# Training set: 684 samples
# Validation set: 254 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs salmon: Train Accuracy = 0.9839, Val Accuracy = 0.6142, Test Accuracy = 0.8039
#
# Training pairwise model for: fries vs soup
# Training set: 551 samples
# Validation set: 209 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs soup: Train Accuracy = 0.9691, Val Accuracy = 0.7081, Test Accuracy = 1.0000
#
# Training pairwise model for: fries vs wings
# Training set: 687 samples
# Validation set: 238 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for fries vs wings: Train Accuracy = 0.9607, Val Accuracy = 0.6555, Test Accuracy = 0.9915
#
# Training pairwise model for: grapes vs gummies
# Training set: 787 samples
# Validation set: 236 samples
# Test set: 92 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs gummies: Train Accuracy = 0.9733, Val Accuracy = 0.7797, Test Accuracy = 0.8913
#
# Training pairwise model for: grapes vs ice-cream
# Training set: 752 samples
# Validation set: 288 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs ice-cream: Train Accuracy = 0.9548, Val Accuracy = 0.8507, Test Accuracy = 0.7177
#
# Training pairwise model for: grapes vs jelly
# Training set: 666 samples
# Validation set: 106 samples
# Test set: 107 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs jelly: Train Accuracy = 0.9685, Val Accuracy = 0.5000, Test Accuracy = 0.9907
#
# Training pairwise model for: grapes vs noodles
# Training set: 652 samples
# Validation set: 126 samples
# Test set: 70 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs noodles: Train Accuracy = 0.9831, Val Accuracy = 0.4762, Test Accuracy = 0.8571
#
# Training pairwise model for: grapes vs pickles
# Training set: 910 samples
# Validation set: 213 samples
# Test set: 186 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs pickles: Train Accuracy = 0.9670, Val Accuracy = 0.4742, Test Accuracy = 0.8548
#
# Training pairwise model for: grapes vs pizza
# Training set: 756 samples
# Validation set: 206 samples
# Test set: 84 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs pizza: Train Accuracy = 0.9775, Val Accuracy = 0.6068, Test Accuracy = 1.0000
#
# Training pairwise model for: grapes vs ribs
# Training set: 707 samples
# Validation set: 137 samples
# Test set: 81 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs ribs: Train Accuracy = 0.9760, Val Accuracy = 0.5328, Test Accuracy = 0.9753
#
# Training pairwise model for: grapes vs salmon
# Training set: 655 samples
# Validation set: 181 samples
# Test set: 102 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs salmon: Train Accuracy = 0.9756, Val Accuracy = 0.6409, Test Accuracy = 0.9510
#
# Training pairwise model for: grapes vs soup
# Training set: 522 samples
# Validation set: 136 samples
# Test set: 57 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs soup: Train Accuracy = 0.9904, Val Accuracy = 0.4706, Test Accuracy = 1.0000
#
# Training pairwise model for: grapes vs wings
# Training set: 658 samples
# Validation set: 165 samples
# Test set: 118 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# Epoch 3/5...
# Epoch 4/5...
# Epoch 5/5...
# Results for grapes vs wings: Train Accuracy = 0.9620, Val Accuracy = 0.5939, Test Accuracy = 0.9746
#
# Training pairwise model for: gummies vs ice-cream
# Training set: 857 samples
# Validation set: 332 samples
# Test set: 124 samples
# =====================================
#
# Epoch 1/5...
# Epoch 2/5...
# ...
# Pair: ('burger', 'grapes'), Train Accuracy: 0.9780, Val Accuracy: 0.8325, Test Accuracy: 0.5423
# Pair: ('burger', 'gummies'), Train Accuracy: 0.9715, Val Accuracy: 0.8921, Test Accuracy: 1.0000
# Pair: ('burger', 'ice-cream'), Train Accuracy: 0.9810, Val Accuracy: 0.9761, Test Accuracy: 0.9839
# Pair: ('burger', 'jelly'), Train Accuracy: 0.9735, Val Accuracy: 0.8829, Test Accuracy: 0.8131
# Pair: ('burger', 'noodles'), Train Accuracy: 0.9366, Val Accuracy: 0.7939, Test Accuracy: 0.9857
# Pair: ('burger', 'pickles'), Train Accuracy: 0.9820, Val Accuracy: 0.8349, Test Accuracy: 0.8763
# Pair: ('burger', 'pizza'), Train Accuracy: 0.9751, Val Accuracy: 0.6682, Test Accuracy: 0.6429
# Pair: ('burger', 'ribs'), Train Accuracy: 0.9786, Val Accuracy: 0.4718, Test Accuracy: 0.8765
# Pair: ('burger', 'salmon'), Train Accuracy: 0.9852, Val Accuracy: 0.5914, Test Accuracy: 0.8137
# Pair: ('burger', 'soup'), Train Accuracy: 0.9689, Val Accuracy: 0.4539, Test Accuracy: 1.0000
# Pair: ('burger', 'wings'), Train Accuracy: 0.9625, Val Accuracy: 0.5176, Test Accuracy: 0.9831
# Pair: ('cabbage', 'candied_fruits'), Train Accuracy: 0.9730, Val Accuracy: 0.7356, Test Accuracy: 0.6271
# Pair: ('cabbage', 'carrots'), Train Accuracy: 0.9662, Val Accuracy: 0.7722, Test Accuracy: 0.3556
# Pair: ('cabbage', 'chips'), Train Accuracy: 0.9444, Val Accuracy: 0.8446, Test Accuracy: 0.9485
# Pair: ('cabbage', 'chocolate'), Train Accuracy: 0.9856, Val Accuracy: 0.9828, Test Accuracy: 1.0000
# Pair: ('cabbage', 'drinks'), Train Accuracy: 0.9813, Val Accuracy: 0.9709, Test Accuracy: 1.0000
# Pair: ('cabbage', 'fries'), Train Accuracy: 0.9561, Val Accuracy: 0.7940, Test Accuracy: 0.9810
# Pair: ('cabbage', 'grapes'), Train Accuracy: 0.9779, Val Accuracy: 0.7625, Test Accuracy: 0.9859
# Pair: ('cabbage', 'gummies'), Train Accuracy: 0.9891, Val Accuracy: 0.9706, Test Accuracy: 1.0000
# Pair: ('cabbage', 'ice-cream'), Train Accuracy: 0.9899, Val Accuracy: 0.9180, Test Accuracy: 1.0000
# Pair: ('cabbage', 'jelly'), Train Accuracy: 0.9844, Val Accuracy: 0.9730, Test Accuracy: 1.0000
# Pair: ('cabbage', 'noodles'), Train Accuracy: 0.9870, Val Accuracy: 0.6596, Test Accuracy: 0.9714
# Pair: ('cabbage', 'pickles'), Train Accuracy: 0.9832, Val Accuracy: 0.6188, Test Accuracy: 0.9731
# Pair: ('cabbage', 'pizza'), Train Accuracy: 0.9737, Val Accuracy: 0.6092, Test Accuracy: 0.6190
# Pair: ('cabbage', 'ribs'), Train Accuracy: 0.9853, Val Accuracy: 0.5143, Test Accuracy: 0.9877
# Pair: ('cabbage', 'salmon'), Train Accuracy: 0.9914, Val Accuracy: 0.7651, Test Accuracy: 0.9804
# Pair: ('cabbage', 'soup'), Train Accuracy: 0.9805, Val Accuracy: 0.7212, Test Accuracy: 0.9474
# Pair: ('cabbage', 'wings'), Train Accuracy: 0.9671, Val Accuracy: 0.7293, Test Accuracy: 0.9915
# Pair: ('candied_fruits', 'carrots'), Train Accuracy: 0.9725, Val Accuracy: 0.7815, Test Accuracy: 0.3444
# Pair: ('candied_fruits', 'chips'), Train Accuracy: 0.9789, Val Accuracy: 0.9912, Test Accuracy: 0.9559
# Pair: ('candied_fruits', 'chocolate'), Train Accuracy: 0.9637, Val Accuracy: 0.9796, Test Accuracy: 1.0000
# Pair: ('candied_fruits', 'drinks'), Train Accuracy: 0.9920, Val Accuracy: 0.9945, Test Accuracy: 1.0000
# Pair: ('candied_fruits', 'fries'), Train Accuracy: 0.9726, Val Accuracy: 0.8307, Test Accuracy: 0.8857
# Pair: ('candied_fruits', 'grapes'), Train Accuracy: 0.9627, Val Accuracy: 0.9625, Test Accuracy: 0.4507
# Pair: ('candied_fruits', 'gummies'), Train Accuracy: 0.9697, Val Accuracy: 0.9261, Test Accuracy: 0.9891
# Pair: ('candied_fruits', 'ice-cream'), Train Accuracy: 0.9738, Val Accuracy: 0.7560, Test Accuracy: 1.0000
# Pair: ('candied_fruits', 'jelly'), Train Accuracy: 0.9632, Val Accuracy: 0.9935, Test Accuracy: 0.9065
# Pair: ('candied_fruits', 'noodles'), Train Accuracy: 0.9836, Val Accuracy: 0.9828, Test Accuracy: 0.8429
# Pair: ('candied_fruits', 'pickles'), Train Accuracy: 0.9802, Val Accuracy: 0.9617, Test Accuracy: 0.9032
# Pair: ('candied_fruits', 'pizza'), Train Accuracy: 0.9604, Val Accuracy: 0.9646, Test Accuracy: 0.9881
# Pair: ('candied_fruits', 'ribs'), Train Accuracy: 0.9615, Val Accuracy: 0.9784, Test Accuracy: 0.9012
# Pair: ('candied_fruits', 'salmon'), Train Accuracy: 0.9942, Val Accuracy: 1.0000, Test Accuracy: 0.9412
# Pair: ('candied_fruits', 'soup'), Train Accuracy: 0.9903, Val Accuracy: 0.9728, Test Accuracy: 1.0000
# Pair: ('candied_fruits', 'wings'), Train Accuracy: 0.9628, Val Accuracy: 0.9202, Test Accuracy: 1.0000
# Pair: ('carrots', 'chips'), Train Accuracy: 0.9446, Val Accuracy: 0.6685, Test Accuracy: 0.6397
# Pair: ('carrots', 'chocolate'), Train Accuracy: 0.9399, Val Accuracy: 0.6781, Test Accuracy: 0.3385
# Pair: ('carrots', 'drinks'), Train Accuracy: 0.9883, Val Accuracy: 0.6316, Test Accuracy: 0.8333
# Pair: ('carrots', 'fries'), Train Accuracy: 0.9894, Val Accuracy: 0.7795, Test Accuracy: 0.8952
# Pair: ('carrots', 'grapes'), Train Accuracy: 0.9645, Val Accuracy: 0.5737, Test Accuracy: 0.5634
# Pair: ('carrots', 'gummies'), Train Accuracy: 0.9816, Val Accuracy: 0.8248, Test Accuracy: 0.9891
# Pair: ('carrots', 'ice-cream'), Train Accuracy: 0.9741, Val Accuracy: 0.8601, Test Accuracy: 0.8387
# Pair: ('carrots', 'jelly'), Train Accuracy: 0.9775, Val Accuracy: 0.6731, Test Accuracy: 1.0000
# Pair: ('carrots', 'noodles'), Train Accuracy: 0.9873, Val Accuracy: 0.7419, Test Accuracy: 0.7286
# Pair: ('carrots', 'pickles'), Train Accuracy: 0.9627, Val Accuracy: 0.7014, Test Accuracy: 0.8387
# Pair: ('carrots', 'pizza'), Train Accuracy: 0.9764, Val Accuracy: 0.4755, Test Accuracy: 0.9167
# Pair: ('carrots', 'ribs'), Train Accuracy: 0.9881, Val Accuracy: 0.7259, Test Accuracy: 1.0000
# Pair: ('carrots', 'salmon'), Train Accuracy: 0.9848, Val Accuracy: 0.8324, Test Accuracy: 0.9216
# Pair: ('carrots', 'soup'), Train Accuracy: 0.9817, Val Accuracy: 0.6493, Test Accuracy: 0.9123
# Pair: ('carrots', 'wings'), Train Accuracy: 0.9811, Val Accuracy: 0.7117, Test Accuracy: 0.8390
# Pair: ('chips', 'chocolate'), Train Accuracy: 0.9732, Val Accuracy: 0.9926, Test Accuracy: 0.9385
# Pair: ('chips', 'drinks'), Train Accuracy: 0.9872, Val Accuracy: 0.9837, Test Accuracy: 1.0000
# Pair: ('chips', 'fries'), Train Accuracy: 0.9436, Val Accuracy: 0.7984, Test Accuracy: 0.8095
# Pair: ('chips', 'grapes'), Train Accuracy: 0.9702, Val Accuracy: 0.9556, Test Accuracy: 0.9577
# Pair: ('chips', 'gummies'), Train Accuracy: 0.9810, Val Accuracy: 0.9598, Test Accuracy: 1.0000
# Pair: ('chips', 'ice-cream'), Train Accuracy: 0.9890, Val Accuracy: 0.9855, Test Accuracy: 0.8952
# Pair: ('chips', 'jelly'), Train Accuracy: 0.9867, Val Accuracy: 1.0000, Test Accuracy: 1.0000
# Pair: ('chips', 'noodles'), Train Accuracy: 0.9889, Val Accuracy: 0.9035, Test Accuracy: 0.9000
# Pair: ('chips', 'pickles'), Train Accuracy: 0.9785, Val Accuracy: 0.9801, Test Accuracy: 0.9570
# Pair: ('chips', 'pizza'), Train Accuracy: 0.9847, Val Accuracy: 0.4227, Test Accuracy: 0.6071
# Pair: ('chips', 'ribs'), Train Accuracy: 0.9815, Val Accuracy: 0.9520, Test Accuracy: 1.0000
# Pair: ('chips', 'salmon'), Train Accuracy: 0.9902, Val Accuracy: 0.9822, Test Accuracy: 0.9118
# Pair: ('chips', 'soup'), Train Accuracy: 0.9809, Val Accuracy: 0.9839, Test Accuracy: 0.9825
# Pair: ('chips', 'wings'), Train Accuracy: 0.9755, Val Accuracy: 0.8758, Test Accuracy: 0.8898
# Pair: ('chocolate', 'drinks'), Train Accuracy: 0.9101, Val Accuracy: 0.5275, Test Accuracy: 0.5417
# Pair: ('chocolate', 'fries'), Train Accuracy: 0.9429, Val Accuracy: 0.6244, Test Accuracy: 0.8095
# Pair: ('chocolate', 'grapes'), Train Accuracy: 0.9650, Val Accuracy: 0.7297, Test Accuracy: 0.5563
# Pair: ('chocolate', 'gummies'), Train Accuracy: 0.9693, Val Accuracy: 0.6719, Test Accuracy: 1.0000
# Pair: ('chocolate', 'ice-cream'), Train Accuracy: 0.9521, Val Accuracy: 0.8238, Test Accuracy: 0.8145
# Pair: ('chocolate', 'jelly'), Train Accuracy: 0.9036, Val Accuracy: 0.1613, Test Accuracy: 1.0000
# Pair: ('chocolate', 'noodles'), Train Accuracy: 0.9669, Val Accuracy: 0.7073, Test Accuracy: 0.3714
# Pair: ('chocolate', 'pickles'), Train Accuracy: 0.9717, Val Accuracy: 0.6627, Test Accuracy: 0.9839
# Pair: ('chocolate', 'pizza'), Train Accuracy: 0.9813, Val Accuracy: 0.4383, Test Accuracy: 1.0000
# Pair: ('chocolate', 'ribs'), Train Accuracy: 0.9703, Val Accuracy: 0.4516, Test Accuracy: 0.9877
# Pair: ('chocolate', 'salmon'), Train Accuracy: 0.9836, Val Accuracy: 0.5985, Test Accuracy: 0.8235
# Pair: ('chocolate', 'soup'), Train Accuracy: 0.9492, Val Accuracy: 0.4130, Test Accuracy: 1.0000
# Pair: ('chocolate', 'wings'), Train Accuracy: 0.9755, Val Accuracy: 0.6446, Test Accuracy: 0.9068
# Pair: ('drinks', 'fries'), Train Accuracy: 0.9617, Val Accuracy: 0.8846, Test Accuracy: 0.9714
# Pair: ('drinks', 'grapes'), Train Accuracy: 0.9689, Val Accuracy: 0.8370, Test Accuracy: 0.9718
# Pair: ('drinks', 'gummies'), Train Accuracy: 0.9831, Val Accuracy: 0.9330, Test Accuracy: 1.0000
# Pair: ('drinks', 'ice-cream'), Train Accuracy: 0.9838, Val Accuracy: 0.9654, Test Accuracy: 0.9919
# Pair: ('drinks', 'jelly'), Train Accuracy: 0.9604, Val Accuracy: 0.8980, Test Accuracy: 1.0000
# Pair: ('drinks', 'noodles'), Train Accuracy: 0.9903, Val Accuracy: 0.7826, Test Accuracy: 0.5857
# Pair: ('drinks', 'pickles'), Train Accuracy: 0.9948, Val Accuracy: 1.0000, Test Accuracy: 0.9839
# Pair: ('drinks', 'pizza'), Train Accuracy: 0.9968, Val Accuracy: 0.9933, Test Accuracy: 0.9881
# Pair: ('drinks', 'ribs'), Train Accuracy: 0.9860, Val Accuracy: 0.7125, Test Accuracy: 0.9012
# Pair: ('drinks', 'salmon'), Train Accuracy: 0.9711, Val Accuracy: 0.9355, Test Accuracy: 1.0000
# Pair: ('drinks', 'soup'), Train Accuracy: 0.9715, Val Accuracy: 0.5443, Test Accuracy: 0.8421
# Pair: ('drinks', 'wings'), Train Accuracy: 0.9904, Val Accuracy: 0.9722, Test Accuracy: 0.9831
# Pair: ('fries', 'grapes'), Train Accuracy: 0.9142, Val Accuracy: 0.6868, Test Accuracy: 0.8732
# Pair: ('fries', 'gummies'), Train Accuracy: 0.9730, Val Accuracy: 0.8317, Test Accuracy: 1.0000
# Pair: ('fries', 'ice-cream'), Train Accuracy: 0.9641, Val Accuracy: 0.9806, Test Accuracy: 0.9597
# Pair: ('fries', 'jelly'), Train Accuracy: 0.9640, Val Accuracy: 0.8268, Test Accuracy: 1.0000
# Pair: ('fries', 'noodles'), Train Accuracy: 0.9633, Val Accuracy: 0.8291, Test Accuracy: 1.0000
# Pair: ('fries', 'pickles'), Train Accuracy: 0.9691, Val Accuracy: 0.7587, Test Accuracy: 0.5054
# Pair: ('fries', 'pizza'), Train Accuracy: 0.9427, Val Accuracy: 0.2975, Test Accuracy: 0.7024
# Pair: ('fries', 'ribs'), Train Accuracy: 0.9538, Val Accuracy: 0.4333, Test Accuracy: 0.9877
# Pair: ('fries', 'salmon'), Train Accuracy: 0.9839, Val Accuracy: 0.6142, Test Accuracy: 0.8039
# Pair: ('fries', 'soup'), Train Accuracy: 0.9691, Val Accuracy: 0.7081, Test Accuracy: 1.0000
# Pair: ('fries', 'wings'), Train Accuracy: 0.9607, Val Accuracy: 0.6555, Test Accuracy: 0.9915
# Pair: ('grapes', 'gummies'), Train Accuracy: 0.9733, Val Accuracy: 0.7797, Test Accuracy: 0.8913
# Pair: ('grapes', 'ice-cream'), Train Accuracy: 0.9548, Val Accuracy: 0.8507, Test Accuracy: 0.7177
# Pair: ('grapes', 'jelly'), Train Accuracy: 0.9685, Val Accuracy: 0.5000, Test Accuracy: 0.9907
# Pair: ('grapes', 'noodles'), Train Accuracy: 0.9831, Val Accuracy: 0.4762, Test Accuracy: 0.8571
# Pair: ('grapes', 'pickles'), Train Accuracy: 0.9670, Val Accuracy: 0.4742, Test Accuracy: 0.8548
# Pair: ('grapes', 'pizza'), Train Accuracy: 0.9775, Val Accuracy: 0.6068, Test Accuracy: 1.0000
# Pair: ('grapes', 'ribs'), Train Accuracy: 0.9760, Val Accuracy: 0.5328, Test Accuracy: 0.9753
# Pair: ('grapes', 'salmon'), Train Accuracy: 0.9756, Val Accuracy: 0.6409, Test Accuracy: 0.9510
# Pair: ('grapes', 'soup'), Train Accuracy: 0.9904, Val Accuracy: 0.4706, Test Accuracy: 1.0000
# Pair: ('grapes', 'wings'), Train Accuracy: 0.9620, Val Accuracy: 0.5939, Test Accuracy: 0.9746
# Pair: ('gummies', 'ice-cream'), Train Accuracy: 0.9732, Val Accuracy: 0.7922, Test Accuracy: 0.9516
# Pair: ('gummies', 'jelly'), Train Accuracy: 0.8911, Val Accuracy: 0.6067, Test Accuracy: 0.9252
# Pair: ('gummies', 'noodles'), Train Accuracy: 0.9723, Val Accuracy: 0.8941, Test Accuracy: 0.9571
# Pair: ('gummies', 'pickles'), Train Accuracy: 0.9773, Val Accuracy: 0.7432, Test Accuracy: 0.6720
# Pair: ('gummies', 'pizza'), Train Accuracy: 0.9803, Val Accuracy: 0.6960, Test Accuracy: 0.1548
# Pair: ('gummies', 'ribs'), Train Accuracy: 0.9655, Val Accuracy: 0.9392, Test Accuracy: 0.5432
# Pair: ('gummies', 'salmon'), Train Accuracy: 0.9566, Val Accuracy: 0.7867, Test Accuracy: 0.6961
# Pair: ('gummies', 'soup'), Train Accuracy: 0.9872, Val Accuracy: 0.8667, Test Accuracy: 0.8421
# Pair: ('gummies', 'wings'), Train Accuracy: 0.9790, Val Accuracy: 0.7656, Test Accuracy: 0.8305
# Pair: ('ice-cream', 'jelly'), Train Accuracy: 0.9389, Val Accuracy: 0.7525, Test Accuracy: 0.6449
# Pair: ('ice-cream', 'noodles'), Train Accuracy: 0.9668, Val Accuracy: 0.9414, Test Accuracy: 0.8857
# Pair: ('ice-cream', 'pickles'), Train Accuracy: 0.9786, Val Accuracy: 0.9061, Test Accuracy: 0.9516
# Pair: ('ice-cream', 'pizza'), Train Accuracy: 0.9782, Val Accuracy: 0.7947, Test Accuracy: 0.6310
# Pair: ('ice-cream', 'ribs'), Train Accuracy: 0.9794, Val Accuracy: 0.8755, Test Accuracy: 0.6914
# Pair: ('ice-cream', 'salmon'), Train Accuracy: 0.9793, Val Accuracy: 0.8448, Test Accuracy: 0.7157
# Pair: ('ice-cream', 'soup'), Train Accuracy: 0.9578, Val Accuracy: 0.8621, Test Accuracy: 0.2456
# Pair: ('ice-cream', 'wings'), Train Accuracy: 0.9657, Val Accuracy: 0.9693, Test Accuracy: 0.8983
# Pair: ('jelly', 'noodles'), Train Accuracy: 0.9355, Val Accuracy: 0.4750, Test Accuracy: 0.3571
# Pair: ('jelly', 'pickles'), Train Accuracy: 0.9810, Val Accuracy: 0.3937, Test Accuracy: 0.7204
# Pair: ('jelly', 'pizza'), Train Accuracy: 0.9527, Val Accuracy: 0.3167, Test Accuracy: 0.1310
# Pair: ('jelly', 'ribs'), Train Accuracy: 0.9320, Val Accuracy: 0.7451, Test Accuracy: 0.3457
# Pair: ('jelly', 'salmon'), Train Accuracy: 0.8983, Val Accuracy: 0.2105, Test Accuracy: 0.1765
# Pair: ('jelly', 'soup'), Train Accuracy: 0.9625, Val Accuracy: 0.1800, Test Accuracy: 0.0351
# Pair: ('jelly', 'wings'), Train Accuracy: 0.9517, Val Accuracy: 0.5696, Test Accuracy: 0.7203
# Pair: ('noodles', 'pickles'), Train Accuracy: 0.9500, Val Accuracy: 0.6803, Test Accuracy: 0.3280
# Pair: ('noodles', 'pizza'), Train Accuracy: 0.8567, Val Accuracy: 0.2357, Test Accuracy: 0.0357
# Pair: ('noodles', 'ribs'), Train Accuracy: 0.9690, Val Accuracy: 0.6620, Test Accuracy: 0.0123
# Pair: ('noodles', 'salmon'), Train Accuracy: 0.9328, Val Accuracy: 0.7478, Test Accuracy: 0.0294
# Pair: ('noodles', 'soup'), Train Accuracy: 0.9614, Val Accuracy: 0.9143, Test Accuracy: 0.9825
# Pair: ('noodles', 'wings'), Train Accuracy: 0.9554, Val Accuracy: 0.3535, Test Accuracy: 0.7797
# Pair: ('pickles', 'pizza'), Train Accuracy: 0.9705, Val Accuracy: 0.4846, Test Accuracy: 0.4048
# Pair: ('pickles', 'ribs'), Train Accuracy: 0.9626, Val Accuracy: 0.9177, Test Accuracy: 0.9877
# Pair: ('pickles', 'salmon'), Train Accuracy: 0.9796, Val Accuracy: 0.8911, Test Accuracy: 0.6961
# Pair: ('pickles', 'soup'), Train Accuracy: 0.9893, Val Accuracy: 0.8599, Test Accuracy: 1.0000
# Pair: ('pickles', 'wings'), Train Accuracy: 0.9718, Val Accuracy: 0.7258, Test Accuracy: 0.9661
# Pair: ('pizza', 'ribs'), Train Accuracy: 0.8848, Val Accuracy: 0.1589, Test Accuracy: 0.0000
# Pair: ('pizza', 'salmon'), Train Accuracy: 0.9177, Val Accuracy: 0.5282, Test Accuracy: 0.9510
# Pair: ('pizza', 'soup'), Train Accuracy: 0.9849, Val Accuracy: 0.5267, Test Accuracy: 1.0000
# Pair: ('pizza', 'wings'), Train Accuracy: 0.9549, Val Accuracy: 0.2123, Test Accuracy: 0.9492
# Pair: ('ribs', 'salmon'), Train Accuracy: 0.9382, Val Accuracy: 0.8651, Test Accuracy: 0.6961
# Pair: ('ribs', 'soup'), Train Accuracy: 0.9744, Val Accuracy: 0.7284, Test Accuracy: 0.9298
# Pair: ('ribs', 'wings'), Train Accuracy: 0.9063, Val Accuracy: 0.8091, Test Accuracy: 0.8220
# Pair: ('salmon', 'soup'), Train Accuracy: 0.9697, Val Accuracy: 0.6800, Test Accuracy: 0.8246
# Pair: ('salmon', 'wings'), Train Accuracy: 0.9493, Val Accuracy: 0.5779, Test Accuracy: 0.9831
# Pair: ('soup', 'wings'), Train Accuracy: 0.9558, Val Accuracy: 0.9450, Test Accuracy: 0.9831

# %%
def pairwise_classification_with_groups(df, dir_path, num_epochs):
    labels = df['label'].unique()
    results = {}
    confusion_data = {}

    unique_labels = df['label'].unique()
    assert len(unique_labels) == 20, "Dataset must contain exactly 20 classes!"

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Initialize a single model to be trained on all pairs
    pairwise_model = CNN_Model(num_classes=2).to(device)
    test_horde = []

    # Train the model on all pair combinations
    for label1, label2 in combinations(labels, 2):
        print(f"Training on pair: {label1} vs {label2}")

        # Create pairwise dataset with groups
        pairwise_df, pairwise_ds, groups = get_pairwise_dataset(df, label1, label2, dir_path)

        # Perform grouped split
        train_dl, val_dl, test_dl = grouped_split(df, [label1, label2], pairwise_ds, groups)
        test_horde.append(test_dl)

        # Train the model
        train_acc, val_acc = train_and_evaluate_pairwise(pairwise_model, train_dl, val_dl, num_epochs)

        # Save intermediate training results for this pair
        results[(label1, label2)] = {
            "train_accuracy": train_acc,
            "val_accuracy": val_acc,
        }


    print("\nFinished training on all pairs. Starting testing...\n")

    # Test the trained model on all pair combinations
    for idx, (label1, label2) in enumerate(combinations(labels, 2)):
        print(f"Testing on pair: {label1} vs {label2}")

        # Create pairwise dataset with groups
        pairwise_df, pairwise_ds, groups = get_pairwise_dataset(df, label1, label2, dir_path)

        # Perform grouped split
        test_dl = test_horde[idx]

        # Evaluate the model on the test set
        test_acc, conf_matrix = test_model(pairwise_model, test_dl, device)

        # Save test results
        results[(label1, label2)]["test_accuracy"] = test_acc
        confusion_data[(label1, label2)] = conf_matrix

        print(f"Test Accuracy for {label1} vs {label2}: {test_acc:.4f}")

    return results, confusion_data

def test_model(model, test_loader, device):
    """Evaluate the model on the test set and record confusion matrix."""
    model.eval()
    correct_predictions = 0
    total_predictions = 0
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            correct_predictions += (predictions == labels).sum().item()
            total_predictions += labels.size(0)

            # Record labels and predictions for confusion matrix
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predictions.cpu().numpy())

    accuracy = correct_predictions / total_predictions
    conf_matrix = confusion_matrix(all_labels, all_predictions)

    return accuracy, conf_matrix

# %%
# Path and dataset initialization
dir_path = os.getcwd()
food_ds = FoodAudioDS(df, dir_path)

unique_labels = df['label'].unique()
assert len(unique_labels) == 20, "Dataset must contain exactly 20 classes!"


# Run pairwise classification with grouped splits
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results, confusion_data = pairwise_classification_with_groups(df, dir_path, num_epochs=2)

# Print summary of results
for pair, metrics in results.items():
    print(f"Pair: {pair}, Train Accuracy: {metrics['train_accuracy']:.4f}, Val Accuracy: {metrics['val_accuracy']:.4f}, Test Accuracy: {metrics['test_accuracy']:.4f}")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from itertools import combinations

# Collect results into a DataFrame for easier processing
pairwise_results = []
for pair, metrics in results.items():
    pairwise_results.append({
        "Label1": pair[0],
        "Label2": pair[1],
        "Train Accuracy": metrics['train_accuracy'],
        "Val Accuracy": metrics['val_accuracy'],
        "Test Accuracy": metrics['test_accuracy']
    })

results_df = pd.DataFrame(pairwise_results)

# Create boxplots for average pairwise classification performances per label
labels = df['label'].unique()
accuracy_per_label = {label: [] for label in labels}

for _, row in results_df.iterrows():
    label1, label2 = row['Label1'], row['Label2']
    test_accuracy = row['Test Accuracy']
    accuracy_per_label[label1].append(test_accuracy)
    accuracy_per_label[label2].append(test_accuracy)

# Prepare data for boxplots
boxplot_data = [accuracies for label, accuracies in accuracy_per_label.items()]
label_names = list(accuracy_per_label.keys())

# Create the boxplot
plt.figure(figsize=(12, 6))
plt.boxplot(boxplot_data, labels=label_names, showfliers=False)
plt.xticks(rotation=45, ha="right")
plt.title("Average Pairwise Classification Accuracies per Label")
plt.ylabel("Accuracy")
plt.xlabel("Labels")
plt.tight_layout()
plt.show()

# Identify the top 10 pairs with highest and lowest test accuracies
top_10_highest = results_df.nlargest(10, 'Test Accuracy')[['Label1', 'Label2', 'Test Accuracy']]
top_10_lowest = results_df.nsmallest(10, 'Test Accuracy')[['Label1', 'Label2', 'Test Accuracy']]
close_to_50 = results_df[(results_df['Test Accuracy'] >= 0.45) & (results_df['Test Accuracy'] <= 0.55)]

# Print top 10 pairs with highest and lowest accuracies
print("Top 10 Pairs with Highest Test Accuracies:")
print(top_10_highest)

print("\nTop 10 Pairs with Lowest Test Accuracies:")
print(top_10_lowest)

print("\nPairs with Test Accuracies Close to 50% (+/-5):")
print(close_to_50[['Label1', 'Label2', 'Test Accuracy']])
# Out:
# C:\Users\Snoop\AppData\Local\Temp\ipykernel_20848\1646776089.py:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(boxplot_data, labels=label_names, showfliers=False)
# Top 10 Pairs with Highest Test Accuracies:
#             Label1 Label2  Test Accuracy
# 14            aloe  pizza            1.0
# 15            aloe   ribs            1.0
# 18            aloe  wings            1.0
# 32          burger  pizza            1.0
# 33          burger   ribs            1.0
# 49         cabbage  pizza            1.0
# 50         cabbage   ribs            1.0
# 53         cabbage  wings            1.0
# 66  candied_fruits   ribs            1.0
# 69  candied_fruits  wings            1.0
#
# Top 10 Pairs with Lowest Test Accuracies:
#              Label1   Label2  Test Accuracy
# 1              aloe  cabbage       0.075472
# 19           burger  cabbage       0.075472
# 39          cabbage    chips       0.301471
# 4              aloe    chips       0.308824
# 22           burger    chips       0.330882
# 70          carrots    chips       0.330882
# 55   candied_fruits    chips       0.338235
# 13             aloe  pickles       0.349462
# 31           burger  pickles       0.349462
# 163           jelly  pickles       0.349462
#
# Pairs with Test Accuracies Close to 50% (+/-5):
#              Label1     Label2  Test Accuracy
# 10             aloe  ice-cream       0.540323
# 11             aloe      jelly       0.457944
# 28           burger  ice-cream       0.500000
# 45          cabbage  ice-cream       0.532258
# 62   candied_fruits      jelly       0.457944
# 76          carrots  ice-cream       0.532258
# 77          carrots      jelly       0.476636
# 85            chips  chocolate       0.538462
# 90            chips  ice-cream       0.491935
# 103       chocolate  ice-cream       0.540323
# 104       chocolate      jelly       0.476636
# 115          drinks  ice-cream       0.524194
# 116          drinks      jelly       0.467290
# 126           fries  ice-cream       0.491935
# 136          grapes  ice-cream       0.516129
# 137          grapes      jelly       0.457944
# 145         gummies  ice-cream       0.516129
# 146         gummies      jelly       0.457944
# 154       ice-cream      jelly       0.467290

# %% [markdown]
# # Visual summary of our data

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
idx = [1, 1007, 1500, 2100, 3000, 3500, 4000, 4400, 5000, 
       5600, 6300, 7000, 7300, 7800, 8700, 9300, 9800, 10300, 
       10600, 11000]

dir_path = os.getcwd()
food_ds = FoodAudioDS(df, dir_path)
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    sgram = food_ds[idx[i]][0]
    s_spec = sgram.squeeze().numpy()
    plt.imshow(s_spec, aspect='auto', origin='lower')
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(food_categories[food_ds[idx[i]][1]])
plt.show()

# %%
plt.figure(figsize=(10,10))
counts = df['label'].value_counts()
counts.plot(kind='barh')

for index, value in enumerate(df['label'].value_counts()):
    plt.text(value, index,
             str(value))
# plt.xlabel('Category')
# plt.ylabel('Count')
# plt.title('Value Counts of Categories')
plt.show()
